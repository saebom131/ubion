# %%
import pandas as pd

# %%
# 파일 로드 
corona = pd.read_csv("../../csv/corona.csv")
# 특정 컬럼을 제거 (Unnamed: 0, seq)
# 컬럼명 순서는 관계 X
corona.drop( ['Unnamed: 0', 'seq'], axis=1, inplace=True )      # axis='columns'도 같은 의미
# 컬럼의 이름을 변경 
corona.columns = ["등록일시", '총사망자', '총확진자', '기준일', 
                  '기준시간', '수정일시', '누적의심자', '누적확진율']
# 복사본 생성
df = corona.copy()
# 등록일시를 기준으로 오름차순 정렬
df.sort_values( ['등록일시'], inplace=True )
# 인덱스를 초기화하고 기존의 인덱스는 제거 
df.reset_index(drop = True, inplace=True)

# %%
df.head()
# Out:
#                       등록일시  총사망자  총확진자       기준일   기준시간  \
# 0  2020-03-10 00:00:00.000    54  7513  20200310  00:00
# 1  2020-03-11 00:00:00.000    60  7755  20200311  00:00
# 2  2020-03-12 00:00:00.000    66  7869  20200312  00:00
# 3  2020-03-13 00:00:00.000    67  7979  20200313  00:00
# 4  2020-03-14 00:00:00.000    72  8086  20200314  00:00
#
#                      수정일시     누적의심자     누적확진율
# 0  2021-10-07 10:30:51.51  210144.0  3.919308
# 1  2021-10-07 10:30:51.51  222395.0  3.804175
# 2  2021-10-07 10:30:51.51  234998.0  3.621744
# 3  2021-10-07 10:30:51.51  248647.0  3.458499
# 4  2021-10-07 10:30:51.51  261335.0  3.318000

# %%
# 파생변수 생성 
# 반복문을 이용하여 일일사망자 컬럼을 추가 
datas = [0]

for i in range(1, len(df), 1):
    # 오늘의 인덱스의 총 사망자 - 전날의 인덱스의 총사망자 
    data = df.loc[i, '총사망자'] - df.loc[i-1, '총사망자']
    datas.append(data)

df['일일사망자'] = datas

# %%
df.head()
# Out:
#                       등록일시  총사망자  총확진자       기준일   기준시간  \
# 0  2020-03-10 00:00:00.000    54  7513  20200310  00:00
# 1  2020-03-11 00:00:00.000    60  7755  20200311  00:00
# 2  2020-03-12 00:00:00.000    66  7869  20200312  00:00
# 3  2020-03-13 00:00:00.000    67  7979  20200313  00:00
# 4  2020-03-14 00:00:00.000    72  8086  20200314  00:00
#
#                      수정일시     누적의심자     누적확진율  일일사망자
# 0  2021-10-07 10:30:51.51  210144.0  3.919308      0
# 1  2021-10-07 10:30:51.51  222395.0  3.804175      6
# 2  2021-10-07 10:30:51.51  234998.0  3.621744      6
# 3  2021-10-07 10:30:51.51  248647.0  3.458499      1
# 4  2021-10-07 10:30:51.51  261335.0  3.318000      5

# %%
# shift() 함수 이용
# shift(n) : 특정 Series데이터에서 n만큼 인덱스의 위치를 이동
df['일일사망자2'] = (df['총사망자'] - df['총사망자'].shift()).fillna(0)

# %%
# diff() 함수 이용
# diff(n) : 특정 Seried 데이터에서 n만큼 인덱스의 위치를 이동한 값과의 차이를 출력
# n은 1이 기본값
df['일일사망자3'] = df['총사망자'].diff().fillna(0)

# %%
df.head()
# Out:
#                       등록일시  총사망자  총확진자       기준일   기준시간  \
# 0  2020-03-10 00:00:00.000    54  7513  20200310  00:00
# 1  2020-03-11 00:00:00.000    60  7755  20200311  00:00
# 2  2020-03-12 00:00:00.000    66  7869  20200312  00:00
# 3  2020-03-13 00:00:00.000    67  7979  20200313  00:00
# 4  2020-03-14 00:00:00.000    72  8086  20200314  00:00
#
#                      수정일시     누적의심자     누적확진율  일일사망자  일일사망자2  일일사망자3
# 0  2021-10-07 10:30:51.51  210144.0  3.919308      0     0.0     0.0
# 1  2021-10-07 10:30:51.51  222395.0  3.804175      6     6.0     6.0
# 2  2021-10-07 10:30:51.51  234998.0  3.621744      6     6.0     6.0
# 3  2021-10-07 10:30:51.51  248647.0  3.458499      1     1.0     1.0
# 4  2021-10-07 10:30:51.51  261335.0  3.318000      5     5.0     5.0

# %%
# 데이터프레임에서 마지막 3개의 컬럼만 추출
# 위치에서 음수가 의미하는것은?
df.iloc[ : , -3: ]
# Out:
#      일일사망자  일일사망자2  일일사망자3
# 0        0     0.0     0.0
# 1        6     6.0     6.0
# 2        6     6.0     6.0
# 3        1     1.0     1.0
# 4        5     5.0     5.0
# ..     ...     ...     ...
# 815      9     9.0     9.0
# 816     20    20.0    20.0
# 817     21    21.0    21.0
# 818     20    20.0    20.0
# 819      6     6.0     6.0
#
# [820 rows x 3 columns]

# %%
(df['일일사망자'] == df['일일사망자2']).sum()
# Out:
# np.int64(820)

# %%
(df['일일사망자'] == df['일일사망자3']).value_counts()
# Out:
# True    820
# Name: count, dtype: int64

# %%
# 통계 요약 정보를 출력하는 함수 
# describe()
df.describe()
# Out:
#                총사망자          총확진자           기준일         누적의심자       누적확진율  \
# count    820.000000  8.200000e+02  8.200000e+02  6.920000e+02  623.000000
# mean    3927.832927  1.913097e+06  2.020897e+07  7.545057e+06    1.556435
# std     6164.310693  4.857030e+06  7.118265e+03  6.172020e+06    0.543014
# min       54.000000  7.513000e+03  2.020031e+07  2.101440e+05    0.902205
# 25%      415.750000  2.393525e+04  2.020100e+07  1.934309e+06    1.078089
# 50%     1812.500000  1.185640e+05  2.021042e+07  6.368310e+06    1.416159
# 75%     3120.500000  3.979915e+05  2.021112e+07  1.216890e+07    1.816009
# max    24305.000000  1.818820e+07  2.022061e+07  2.151807e+07    3.919308
#
#             일일사망자      일일사망자2      일일사망자3
# count  820.000000  820.000000  820.000000
# mean    29.574390   29.574390   29.574390
# std     68.530863   68.530863   68.530863
# min     -2.000000   -2.000000   -2.000000
# 25%      2.000000    2.000000    2.000000
# 50%      5.000000    5.000000    5.000000
# 75%     20.000000   20.000000   20.000000
# max    469.000000  469.000000  469.000000

# %%
# 통계 정보를 확인하니 일일사망자 데이터에 음수가 확인
# 일일사망자 데이터에서 음수인 데이터를 확인하자
# 조건식 : 일일사망자 컬럼의 데이터가 0보다 작은
flag = df['일일사망자'] < 0

# %%
# flag는 인덱스의 조건식으로 사용이 가능
# 인덱스의 조건식을 사용하는 것은 loc
df.loc[flag, ]
# Out:
#                         등록일시  총사망자    총확진자       기준일   기준시간  \
# 446  2021-05-30 00:00:00.000  1957  139907  20210530  00:00
#
#                        수정일시      누적의심자     누적확진율  일일사망자  일일사망자2  일일사망자3
# 446  2021-10-07 10:30:51.51  9747612.0  1.454166     -2    -2.0    -2.0

# %%
# 해당 날짜 데이터만 가지고 데이터의 문제는 발견이 힘들다. 
# +- 2일치 데이터를 확인 
df.loc[444:448, ]
# Out:
#                         등록일시  총사망자    총확진자       기준일   기준시간  \
# 444  2021-05-29 00:00:00.000  1951  139427  20210529  00:00
# 445    2021-05-30 00:00:00.0  1959  140337  20210531  00:00
# 446  2021-05-30 00:00:00.000  1957  139907  20210530  00:00
# 447  2021-06-01 00:00:00.000  1963  140796  20210601  00:00
# 448  2021-06-02 00:00:00.000  1965  141473  20210602  00:00
#
#                         수정일시      누적의심자     누적확진율  일일사망자  일일사망자2  일일사망자3
# 444   2021-10-07 10:30:51.51  9733588.0  1.450884      5     5.0     5.0
# 445  2021-10-14 13:48:56.821  9761156.0  1.456805      8     8.0     8.0
# 446   2021-10-07 10:30:51.51  9747612.0  1.454166     -2    -2.0    -2.0
# 447   2021-10-07 10:30:51.51  9798400.0  1.455890      6     6.0     6.0
# 448   2021-10-07 10:30:51.51  9834348.0  1.457668      2     2.0     2.0

# %%
# index는 445, column은 '등록일시' 인 데이터를 변경 
df.loc[445, '등록일시'] = '2021-05-31 00:00:00.000'

# %%
df.loc[444:448, ]
# Out:
#                         등록일시  총사망자    총확진자       기준일   기준시간  \
# 444  2021-05-29 00:00:00.000  1951  139427  20210529  00:00
# 445  2021-05-31 00:00:00.000  1959  140337  20210531  00:00
# 446  2021-05-30 00:00:00.000  1957  139907  20210530  00:00
# 447  2021-06-01 00:00:00.000  1963  140796  20210601  00:00
# 448  2021-06-02 00:00:00.000  1965  141473  20210602  00:00
#
#                         수정일시      누적의심자     누적확진율  일일사망자  일일사망자2  일일사망자3
# 444   2021-10-07 10:30:51.51  9733588.0  1.450884      5     5.0     5.0
# 445  2021-10-14 13:48:56.821  9761156.0  1.456805      8     8.0     8.0
# 446   2021-10-07 10:30:51.51  9747612.0  1.454166     -2    -2.0    -2.0
# 447   2021-10-07 10:30:51.51  9798400.0  1.455890      6     6.0     6.0
# 448   2021-10-07 10:30:51.51  9834348.0  1.457668      2     2.0     2.0

# %% [markdown]
# 1. 마지막 3개의 컬럼을 제거
# 2. 등록일시를 기준으로 오름차순 정렬
# 3. 인덱스를 초기화하고 기존의 인덱스는 제거
# 4. '일일사망자' 컬럼을 생성하여 shift() 함수를 이용하여 데이터를 대입
# 5. '일일확진자' 컬럼을 생성하여 diff() 함수를 이용하여 데이터를 대입
# 6. 통계정보를 통해서 일일사망자, 일일확진자 컬럼에 음수가 존재하는가? 확이

# %%
df
# Out:
#                         등록일시   총사망자      총확진자       기준일   기준시간  \
# 0    2020-03-10 00:00:00.000     54      7513  20200310  00:00
# 1    2020-03-11 00:00:00.000     60      7755  20200311  00:00
# 2    2020-03-12 00:00:00.000     66      7869  20200312  00:00
# 3    2020-03-13 00:00:00.000     67      7979  20200313  00:00
# 4    2020-03-14 00:00:00.000     72      8086  20200314  00:00
# ..                       ...    ...       ...       ...    ...
# 815  2022-06-04 08:56:49.219  24238  18153814  20220604  00:00
# 816  2022-06-05 08:53:19.426  24258  18163648  20220605  00:00
# 817  2022-06-06 09:00:06.734  24279  18168670  20220606  00:00
# 818  2022-06-07 09:09:00.897  24299  18174842  20220607  00:00
# 819  2022-06-08 09:09:05.982  24305  18188200  20220608  00:00
#
#                         수정일시     누적의심자     누적확진율  일일사망자  일일사망자2  일일사망자3
# 0     2021-10-07 10:30:51.51  210144.0  3.919308      0     0.0     0.0
# 1     2021-10-07 10:30:51.51  222395.0  3.804175      6     6.0     6.0
# 2     2021-10-07 10:30:51.51  234998.0  3.621744      6     6.0     6.0
# 3     2021-10-07 10:30:51.51  248647.0  3.458499      1     1.0     1.0
# 4     2021-10-07 10:30:51.51  261335.0  3.318000      5     5.0     5.0
# ..                       ...       ...       ...    ...     ...     ...
# 815  2022-06-08 09:11:26.303       NaN       NaN      9     9.0     9.0
# 816  2022-06-08 09:11:04.758       NaN       NaN     20    20.0    20.0
# 817  2022-06-08 09:10:50.441       NaN       NaN     21    21.0    21.0
# 818  2022-06-08 09:10:36.846       NaN       NaN     20    20.0    20.0
# 819                      NaN       NaN       NaN      6     6.0     6.0
#
# [820 rows x 11 columns]

# %%
df.drop(['일일사망자', '일일사망자2', '일일사망자3'], axis=1, inplace=True)
# df.drop(df.columns[-3:], axis=1)
# df.iloc[:, :-3]
df.sort_values(['등록일시'], inplace=True)
df.reset_index(drop = True, inplace=True)

# %%
df
# Out:
#                         등록일시   총사망자      총확진자       기준일   기준시간  \
# 0    2020-03-10 00:00:00.000     54      7513  20200310  00:00
# 1    2020-03-11 00:00:00.000     60      7755  20200311  00:00
# 2    2020-03-12 00:00:00.000     66      7869  20200312  00:00
# 3    2020-03-13 00:00:00.000     67      7979  20200313  00:00
# 4    2020-03-14 00:00:00.000     72      8086  20200314  00:00
# ..                       ...    ...       ...       ...    ...
# 815  2022-06-04 08:56:49.219  24238  18153814  20220604  00:00
# 816  2022-06-05 08:53:19.426  24258  18163648  20220605  00:00
# 817  2022-06-06 09:00:06.734  24279  18168670  20220606  00:00
# 818  2022-06-07 09:09:00.897  24299  18174842  20220607  00:00
# 819  2022-06-08 09:09:05.982  24305  18188200  20220608  00:00
#
#                         수정일시     누적의심자     누적확진율
# 0     2021-10-07 10:30:51.51  210144.0  3.919308
# 1     2021-10-07 10:30:51.51  222395.0  3.804175
# 2     2021-10-07 10:30:51.51  234998.0  3.621744
# 3     2021-10-07 10:30:51.51  248647.0  3.458499
# 4     2021-10-07 10:30:51.51  261335.0  3.318000
# ..                       ...       ...       ...
# 815  2022-06-08 09:11:26.303       NaN       NaN
# 816  2022-06-08 09:11:04.758       NaN       NaN
# 817  2022-06-08 09:10:50.441       NaN       NaN
# 818  2022-06-08 09:10:36.846       NaN       NaN
# 819                      NaN       NaN       NaN
#
# [820 rows x 8 columns]

# %%
# shift() 함수 이용
# shift(n) : 특정 Series데이터에서 n만큼 인덱스의 위치를 이동
df['일일사망자'] = (df['총사망자'] - df['총사망자'].shift()).fillna(0)

# %%
# diff() 함수 이용
# diff(n) : 특정 Seried 데이터에서 n만큼 인덱스의 위치를 이동한 값과의 차이를 출력
# n은 1이 기본값
df['일일확진자'] = (df['총확진자']).diff().fillna(0)

# %%
df
# Out:
#                         등록일시   총사망자      총확진자       기준일   기준시간  \
# 0    2020-03-10 00:00:00.000     54      7513  20200310  00:00
# 1    2020-03-11 00:00:00.000     60      7755  20200311  00:00
# 2    2020-03-12 00:00:00.000     66      7869  20200312  00:00
# 3    2020-03-13 00:00:00.000     67      7979  20200313  00:00
# 4    2020-03-14 00:00:00.000     72      8086  20200314  00:00
# ..                       ...    ...       ...       ...    ...
# 815  2022-06-04 08:56:49.219  24238  18153814  20220604  00:00
# 816  2022-06-05 08:53:19.426  24258  18163648  20220605  00:00
# 817  2022-06-06 09:00:06.734  24279  18168670  20220606  00:00
# 818  2022-06-07 09:09:00.897  24299  18174842  20220607  00:00
# 819  2022-06-08 09:09:05.982  24305  18188200  20220608  00:00
#
#                         수정일시     누적의심자     누적확진율  일일사망자    일일확진자
# 0     2021-10-07 10:30:51.51  210144.0  3.919308    0.0      0.0
# 1     2021-10-07 10:30:51.51  222395.0  3.804175    6.0    242.0
# 2     2021-10-07 10:30:51.51  234998.0  3.621744    6.0    114.0
# 3     2021-10-07 10:30:51.51  248647.0  3.458499    1.0    110.0
# 4     2021-10-07 10:30:51.51  261335.0  3.318000    5.0    107.0
# ..                       ...       ...       ...    ...      ...
# 815  2022-06-08 09:11:26.303       NaN       NaN    9.0  12039.0
# 816  2022-06-08 09:11:04.758       NaN       NaN   20.0   9834.0
# 817  2022-06-08 09:10:50.441       NaN       NaN   21.0   5022.0
# 818  2022-06-08 09:10:36.846       NaN       NaN   20.0   6172.0
# 819                      NaN       NaN       NaN    6.0  13358.0
#
# [820 rows x 10 columns]

# %%
df.describe()
# Out:
#                총사망자          총확진자           기준일         누적의심자       누적확진율  \
# count    820.000000  8.200000e+02  8.200000e+02  6.920000e+02  623.000000
# mean    3927.832927  1.913097e+06  2.020897e+07  7.545057e+06    1.556435
# std     6164.310693  4.857030e+06  7.118265e+03  6.172020e+06    0.543014
# min       54.000000  7.513000e+03  2.020031e+07  2.101440e+05    0.902205
# 25%      415.750000  2.393525e+04  2.020100e+07  1.934309e+06    1.078089
# 50%     1812.500000  1.185640e+05  2.021042e+07  6.368310e+06    1.416159
# 75%     3120.500000  3.979915e+05  2.021112e+07  1.216890e+07    1.816009
# max    24305.000000  1.818820e+07  2.022061e+07  2.151807e+07    3.919308
#
#             일일사망자          일일확진자
# count  820.000000     820.000000
# mean    29.574390   22171.569512
# std     68.530435   71013.844067
# min      0.000000       0.000000
# 25%      2.000000     125.000000
# 50%      5.000000     634.000000
# 75%     20.000000    2782.750000
# max    469.000000  621204.000000

# %%
# 일일사망자 데이터에서 음수인 데이터를 확인하자
# 조건식 : 일일사망자 컬럼의 데이터가 0보다 작은
flag = df['일일사망자'] < 0

# %%
# flag는 인덱스의 조건식으로 사용이 가능
# 인덱스의 조건식을 사용하는 것은 loc
df.loc[flag, ]
# Out:
# Empty DataFrame
# Columns: [등록일시, 총사망자, 총확진자, 기준일, 기준시간, 수정일시, 누적의심자, 누적확진율, 일일사망자, 일일확진자]
# Index: []

# %%
flag2 = df['일일확진자'] < 0
df.loc[flag, ]
# Out:
# Empty DataFrame
# Columns: [등록일시, 총사망자, 총확진자, 기준일, 기준시간, 수정일시, 누적의심자, 누적확진율, 일일사망자, 일일확진자]
# Index: []

# %%
# DataFrame을 csv 파일로 저장
df.to_csv('./corona.csv')       # ./(현재 파일의 위치) 생략 가능
# Unnamed: 0으로 인덱스 생성(0, 1, 2, ...)

# %%
df.to_csv('./corona.csv', index=False)
# Unnamed: 0 이라는 인덱스 컬럼 생성X

# %%
pd.read_csv('corona.csv')
# Out:
#                         등록일시   총사망자      총확진자       기준일   기준시간  \
# 0    2020-03-10 00:00:00.000     54      7513  20200310  00:00
# 1    2020-03-11 00:00:00.000     60      7755  20200311  00:00
# 2    2020-03-12 00:00:00.000     66      7869  20200312  00:00
# 3    2020-03-13 00:00:00.000     67      7979  20200313  00:00
# 4    2020-03-14 00:00:00.000     72      8086  20200314  00:00
# ..                       ...    ...       ...       ...    ...
# 815  2022-06-04 08:56:49.219  24238  18153814  20220604  00:00
# 816  2022-06-05 08:53:19.426  24258  18163648  20220605  00:00
# 817  2022-06-06 09:00:06.734  24279  18168670  20220606  00:00
# 818  2022-06-07 09:09:00.897  24299  18174842  20220607  00:00
# 819  2022-06-08 09:09:05.982  24305  18188200  20220608  00:00
#
#                         수정일시     누적의심자     누적확진율  일일사망자    일일확진자
# 0     2021-10-07 10:30:51.51  210144.0  3.919308    0.0      0.0
# 1     2021-10-07 10:30:51.51  222395.0  3.804175    6.0    242.0
# 2     2021-10-07 10:30:51.51  234998.0  3.621744    6.0    114.0
# 3     2021-10-07 10:30:51.51  248647.0  3.458499    1.0    110.0
# 4     2021-10-07 10:30:51.51  261335.0  3.318000    5.0    107.0
# ..                       ...       ...       ...    ...      ...
# 815  2022-06-08 09:11:26.303       NaN       NaN    9.0  12039.0
# 816  2022-06-08 09:11:04.758       NaN       NaN   20.0   9834.0
# 817  2022-06-08 09:10:50.441       NaN       NaN   21.0   5022.0
# 818  2022-06-08 09:10:36.846       NaN       NaN   20.0   6172.0
# 819                      NaN       NaN       NaN    6.0  13358.0
#
# [820 rows x 10 columns]

# %%
# 파일을 로드할 때 특정 컬럼 인덱스로 사용
pd.read_csv('corona.csv', index_col=[0])        # 첫 번째 컬럼을 인덱스로
pd.read_csv('corona.csv', index_col=[0,1])      # 여러 개의 컬럼을 인덱스로 사용 가능
# Out:
#                                    총확진자       기준일   기준시간  \
# 등록일시                    총사망자
# 2020-03-10 00:00:00.000 54         7513  20200310  00:00
# 2020-03-11 00:00:00.000 60         7755  20200311  00:00
# 2020-03-12 00:00:00.000 66         7869  20200312  00:00
# 2020-03-13 00:00:00.000 67         7979  20200313  00:00
# 2020-03-14 00:00:00.000 72         8086  20200314  00:00
# ...                                 ...       ...    ...
# 2022-06-04 08:56:49.219 24238  18153814  20220604  00:00
# 2022-06-05 08:53:19.426 24258  18163648  20220605  00:00
# 2022-06-06 09:00:06.734 24279  18168670  20220606  00:00
# 2022-06-07 09:09:00.897 24299  18174842  20220607  00:00
# 2022-06-08 09:09:05.982 24305  18188200  20220608  00:00
#
#                                                   수정일시     누적의심자     누적확진율  \
# 등록일시                    총사망자
# 2020-03-10 00:00:00.000 54      2021-10-07 10:30:51.51  210144.0  3.919308
# 2020-03-11 00:00:00.000 60      2021-10-07 10:30:51.51  222395.0  3.804175
# 2020-03-12 00:00:00.000 66      2021-10-07 10:30:51.51  234998.0  3.621744
# 2020-03-13 00:00:00.000 67      2021-10-07 10:30:51.51  248647.0  3.458499
# 2020-03-14 00:00:00.000 72      2021-10-07 10:30:51.51  261335.0  3.318000
# ...                                                ...       ...       ...
# 2022-06-04 08:56:49.219 24238  2022-06-08 09:11:26.303       NaN       NaN
# 2022-06-05 08:53:19.426 24258  2022-06-08 09:11:04.758       NaN       NaN
# 2022-06-06 09:00:06.734 24279  2022-06-08 09:10:50.441       NaN       NaN
# 2022-06-07 09:09:00.897 24299  2022-06-08 09:10:36.846       NaN       NaN
# 2022-06-08 09:09:05.982 24305                      NaN       NaN       NaN
#
#                                일일사망자    일일확진자
# 등록일시                    총사망자
# 2020-03-10 00:00:00.000 54       0.0      0.0
# 2020-03-11 00:00:00.000 60       6.0    242.0
# 2020-03-12 00:00:00.000 66       6.0    114.0
# 2020-03-13 00:00:00.000 67       1.0    110.0
# 2020-03-14 00:00:00.000 72       5.0    107.0
# ...                              ...      ...
# 2022-06-04 08:56:49.219 24238    9.0  12039.0
# 2022-06-05 08:53:19.426 24258   20.0   9834.0
# 2022-06-06 09:00:06.734 24279   21.0   5022.0
# 2022-06-07 09:09:00.897 24299   20.0   6172.0
# 2022-06-08 09:09:05.982 24305    6.0  13358.0
#
# [820 rows x 8 columns]

# %%
pd.read_csv('corona.csv', index_col=[0], usecols=[0,1,2])
# Out:
#                           총사망자      총확진자
# 등록일시
# 2020-03-10 00:00:00.000     54      7513
# 2020-03-11 00:00:00.000     60      7755
# 2020-03-12 00:00:00.000     66      7869
# 2020-03-13 00:00:00.000     67      7979
# 2020-03-14 00:00:00.000     72      8086
# ...                        ...       ...
# 2022-06-04 08:56:49.219  24238  18153814
# 2022-06-05 08:53:19.426  24258  18163648
# 2022-06-06 09:00:06.734  24279  18168670
# 2022-06-07 09:09:00.897  24299  18174842
# 2022-06-08 09:09:05.982  24305  18188200
#
# [820 rows x 2 columns]
