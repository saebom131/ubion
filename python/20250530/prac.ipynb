# %%
import os
from glob import glob
import pandas as pd

# %%
os.listdir('../../csv/2017')[0]
# Out:
# '201701_expense_list.csv'

# %%
list = []
for i in range(12):
    list.append(os.listdir('../../csv/2017')[i])
list
# Out:
# ['201701_expense_list.csv',
#  '201702_expense_list.csv',
#  '201703_expense_list.csv',
#  '201704_expense_list.csv',
#  '201705_expense_list.csv',
#  '201706_expense_list.csv',
#  '201707_expense_list.csv',
#  '201708_expense_list.csv',
#  '201709_expense_list.csv',
#  '201710_expense_list.csv',
#  '201711_expense_list.csv',
#  '201712_expense_list.csv']

# %%
list[0]
# Out:
# '201701_expense_list.csv'

# %%
'../../csv/'+list[0]
# Out:
# '../../csv/201701_expense_list.csv'

# %%
pd.read_csv('../../csv/2017/'+list[0])
# Out:
#            nid                                       title  \
# 0     11430252                2017년 1월 장애인복지정책과 업무추진비 집행내역
# 1     11430252                2017년 1월 장애인복지정책과 업무추진비 집행내역
# 2     11430252                2017년 1월 장애인복지정책과 업무추진비 집행내역
# 3     11430252                2017년 1월 장애인복지정책과 업무추진비 집행내역
# 4     11430252                2017년 1월 장애인복지정책과 업무추진비 집행내역
# ...        ...                                         ...
# 5512  15513286  2017년 1월 서울시본청_경제진흥본부_경제기획관_투자유치과 업무추진비 내역
# 5513  15513286  2017년 1월 서울시본청_경제진흥본부_경제기획관_투자유치과 업무추진비 내역
# 5514  15513286  2017년 1월 서울시본청_경제진흥본부_경제기획관_투자유치과 업무추진비 내역
# 5515  15513286  2017년 1월 서울시본청_경제진흥본부_경제기획관_투자유치과 업무추진비 내역
# 5516  15513286  2017년 1월 서울시본청_경제진흥본부_경제기획관_투자유치과 업무추진비 내역
#
#                                              url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0     http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 1     http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# ...

# %%
expense = pd.concat([pd.read_csv('../../csv/2017/'+list[0]), pd.read_csv('../../csv/2017/'+list[1])])

# %%
expense.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11285 entries, 0 to 5767
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nid                11285 non-null  int64
#  1   title              11285 non-null  object
#  2   url                11285 non-null  object
#  3   dept_nm_lvl_1      11285 non-null  object
#  4   dept_nm_lvl_2      11263 non-null  object
#  5   dept_nm_lvl_3      9902 non-null   object
#  6   dept_nm_lvl_4      2714 non-null   object
#  7   dept_nm_lvl_5      498 non-null    object
#  8   exec_yr            11285 non-null  int64
#  9   exec_month         11285 non-null  int64
#  10  expense_budget     565 non-null    float64
#  11  expense_execution  442 non-null    float64
#  12  category           200 non-null    object
#  13  dept_nm_full       11285 non-null  object
#  14  exec_dt            11285 non-null  object
#  15  exec_loc           11189 non-null  object
# ...

# %%
for i in range(2, 12):
    expense = pd.concat([expense, pd.read_csv('../../csv/2017/'+list[i])])
expense.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70132 entries, 0 to 7285
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nid                70132 non-null  int64
#  1   title              70132 non-null  object
#  2   url                70132 non-null  object
#  3   dept_nm_lvl_1      70132 non-null  object
#  4   dept_nm_lvl_2      70074 non-null  object
#  5   dept_nm_lvl_3      61262 non-null  object
#  6   dept_nm_lvl_4      17939 non-null  object
#  7   dept_nm_lvl_5      3474 non-null   object
#  8   exec_yr            70132 non-null  int64
#  9   exec_month         70132 non-null  int64
#  10  expense_budget     3108 non-null   float64
#  11  expense_execution  2805 non-null   float64
#  12  category           1259 non-null   object
#  13  dept_nm_full       70053 non-null  object
#  14  exec_dt            70132 non-null  object
#  15  exec_loc           69360 non-null  object
# ...

# %%
expense
# Out:
#            nid                            title  \
# 0     11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 1     11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 2     11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 3     11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 4     11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# ...        ...                              ...
# 7281  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 7282  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 7283  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 7284  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 7285  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
#
#                                              url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0     http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 1     http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 2     http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# ...

# %%
exp = []
for i in range(12):
    exp.append(pd.read_csv('../../csv/2017/'+list[i]))

# %%
len(exp[0])
# Out:
# 5517

# %%
sum = 0
for i in range(12):
    sum += len(exp[i])

# %%
sum
# Out:
# 70132
