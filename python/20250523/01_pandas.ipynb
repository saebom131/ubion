# %% [markdown]
# ### <pandas를 이용해 외부의 데이터파일 로드>
# - csv, tsv
#     - 가장 단순한 형태의 데이터 파일
#     - pandas 안에 있는 read_csv() 이용
#     - csv 데이터를 ','를 기준으로 나눠준다.
#         - read_csv()는 기본적으로 데이터를 ',' 기준으로 잘라준다.
#     - tsv 데이터는 '\t'을 기준으로 나눠준다.
#         - read_csv() 함수를 호출할 때 매개변수 sep의 값을 '\t'를 대입하여 실행
#
# - json
#     - python으로 생각하면 dict 형태의 데이터 파일
#     - pandas 안에 있는 read_json() 이용
#
# - xml
#     - html 구조 언어와 같이 tag 데이터 구성
#     - pandas 안에 있는 read_xml() 이용
#
# - 공통적으로 사용되는 매개변수
#     - encoding 매개변수
#         - 기본값은 'UTF-8'
#         - 데이터 파일을 로드하는데 해당하는 파일에서 한글이 존재할 때 종종 에러 발생(decode error)
#             - encoding 매개변수를 'CP949', 'EUC-KR'로 변경하여 해결
#
# - excel파일 (.xls / .xlsx)
#     - 엑셀 데이터 파일
#     - read_excel() 함수 이용
#     - 특정 엑셀 파일을 로드할 때는 추가적인 라이브러리(openpyxl) 설치가 필요한 경우가 존재
#     - encoding이라는 매개변수가 존재하지 않음

# %%
# pandas 라이브러리 로드(부착)
import pandas as pd

# %%
# read_csv(파일의 경로)
# 경로 (절대경로, 상대경로 모두 사용 가능)
# ccv 폴더 안의 AAPL.csv 파일을 로드
# 절대 경로 사용
# df1 = pd.read_csv('C:\ubion\csv\AAPL.csv')     => 오류발생(\ 이스케이프 문자 처리되는 문제)
df1 = pd.read_csv("C:\\ubion\\csv\\AAPL.csv")       # 1. \ 하나더 추가

# %%
df2 = pd.read_csv("C:/ubion/csv/AAPL.csv")      # 2. 혹은 /(슬래쉬)로 변경해 사용

# %%
df1 = pd.read_csv(
    # 3. r : raw string => \(역슬래쉬)를 이스케이프 문자로 처리하지 않아 문제 해결
    r"C:\ubion\csv\AAPL.csv"                    
)

# %%
# 상대 경로 사용
# 상위 폴더 이동 -> 상위 폴더 이동 -> csv 폴더로 이동 -> 해당 파일 name
df3 = pd.read_csv("../../csv/AAPL.csv")

# %%
# 데이터프레임의 상위의 데이터만 추출하여 출력
# head() 함수가 위치하는 곳은 DataFrame ㅐ부
# 상위의 5개 데이터를 확인  => 디폴트가 5개
print(df3.head())
# Out:
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.410525  117258400.0
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.389106   43971200.0
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.360548   26432000.0
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.369472   21610400.0
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.380182   18362400.0

# %%
# 상위 3개 데이터 확인
df3.head(3)
# Out:
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.410525  117258400.0
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.389106   43971200.0
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.360548   26432000.0

# %%
# json 파일 로드
pd.read_json("../../csv/2021/202101_expense_list.json")

# %%
pd.read_excel("../../csv/2021/202101_expense_list.xlsx")
# openpyxl 모듈 없으면 실행 실패(에러)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\toqha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\toqha\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:984, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.read_excel("../../csv/2021/202101_expense_list.xlsx")
#
# File c:\Users\toqha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\toqha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File c:\Users\toqha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)
#     539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)
#     550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File c:\Users\toqha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
# excel 파일 로드시 모듈 에러 발생시(openpyxl)
# openpyxl 모듈을 설치 => pip install openpyxl

pd.read_excel("../../csv/2021/202101_expense_list.xlsx")
# Out:
#            nid                                          title  \
# 0     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 1     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 2     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 3     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 4     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# ...        ...                                            ...
# 4873  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4874  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4875  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4876  22241159  2021년 1월 사업소 상수도사업본부 중부수도사업소 요금과 업무추진비 - 부서운영
# 4877  22241159  2021년 1월 사업소 상수도사업본부 중부수도사업소 요금과 업무추진비 - 부서운영
#
#                                              url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# 1     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# 2     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# 3     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# 4     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# ...                                          ...           ...           ...
# 4873  http://opengov.seoul.go.kr/public/22241154         서울시본청        주택건축본부
# 4874  http://opengov.seoul.go.kr/public/22241154         서울시본청        주택건축본부
# 4875  http://opengov.seoul.go.kr/public/22241154         서울시본청        주택건축본부
# 4876  http://opengov.seoul.go.kr/public/22241159           사업소       상수도사업본부
# 4877  http://opengov.seoul.go.kr/public/22241159           사업소       상수도사업본부
#
#      dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr  exec_month  ...  \
# 0          중랑물재생센터           NaN           NaN     2021           1  ...
# 1          중랑물재생센터           NaN           NaN     2021           1  ...
# 2          중랑물재생센터           NaN           NaN     2021           1  ...
# 3          중랑물재생센터           NaN           NaN     2021           1  ...
# 4          중랑물재생센터           NaN           NaN     2021           1  ...
# ...            ...           ...           ...      ...         ...  ...
# 4873      지역건축안전센터           NaN           NaN     2021           1  ...
# 4874      지역건축안전센터           NaN           NaN     2021           1  ...
# 4875      지역건축안전센터           NaN           NaN     2021           1  ...
# 4876       중부수도사업소           요금과           NaN     2021           1  ...
# 4877       중부수도사업소           요금과           NaN     2021           1  ...
#
#       expense_execution  category     dept_nm_full           exec_dt  \
# 0                   NaN       NaN      중랑물재생센터 관리과  2021-01-25 00:00
# 1                   NaN       NaN      중랑물재생센터 운영과  2021-01-22 00:00
# 2                   NaN       NaN    중랑물재생센터 시설보수과  2021-01-21 00:00
# 3                   NaN       NaN      중랑물재생센터 운영과  2021-01-21 00:00
# 4                   NaN       NaN      중랑물재생센터 운영과  2021-01-21 00:00
# ...                 ...       ...              ...               ...
# 4873                NaN       NaN  주택건축본부 지역건축안전센터  2021-01-06 12:33
# 4874                NaN       NaN  주택건축본부 지역건축안전센터  2021-01-05 18:25
# 4875                NaN       NaN  주택건축본부 지역건축안전센터  2021-01-04 12:35
# 4876                NaN       NaN         중부수도 요금과  2021-01-27 15:19
# 4877                NaN       NaN         중부수도 요금과  2021-01-22 00:00
#
#                      exec_loc                   exec_purpose       target_nm  \
# 0                         NaN                      소속직원 경조사비        김광옥, 김용성
# 1                         복시루                운영과 다과구매-전출직원선물             NaN
# 2                         떡시루                       소속직원 송별떡     시설보수과장외 27명
# 3                      서울시청매점                운영과 다과구매-전출직원선물             NaN
# 4                         복시루                운영과 다과구매-전출직원선물             NaN
# ...                       ...                            ...             ...
# 4873      곰비임비(중구 세종대로11길 45)  중소형 민간건축공사장 안전대책 관련 간담회 비용 지급  지역건축안전센터장 외 2명
# 4874       본죽&비빔밥(중구 세종대로 80)   소규모 노후 건축물 안전점검 관련 간담회 비용 지급  지역건축안전센터장 외 2명
# 4875     크레이지후라이(중구 서소문로 124)    겨울방학 아르바이트 대학생 격려 간담회 비용 지급  지역건축안전센터장 외 2명
# 4876  가메골에프엔비㈜(중구 남대문시장4길 42)               부서 직원 교육 및 신년간담회      요금과 직원 20명
# 4877        추어탕(중구 다산로 75 3층)                       간부 신년간담회          소장외 3명
#
#      payment_method exec_amount  bimok
# 0                현금      100000    NaN
# 1                카드       90000    NaN
# 2                카드       80000    NaN
# 3              제로페이       48000    NaN
# 4                카드       75000    NaN
# ...             ...         ...    ...
# 4873           제로페이       35000    NaN
# 4874           제로페이       21000    NaN
# 4875           제로페이       40000    NaN
# 4876             카드       64000    NaN
# 4877             카드       36000    NaN
#
# [4878 rows x 21 columns]

# %%
# 데이터 파일명에 한글이 존재할 때 종종 에러 발생
# 해결 방법은 encoding을 cp949 / euc-kr 로 변경
pd.read_csv("../../csv/주민등록.csv", encoding='cp949')
# Out:
#    자치구코드(atdrc_code_se)  자치구명(atdrc_nm)  년월(년월)  총인구수(tot_popltn_co)  \
# 0                   금천구           11110  201907               228755
# 1                  서대문구           11290  201607               153780
# 2                   양천구           11740  201804               594315
# 3                   은평구           11200  202004               345156
# 4                   마포구           11260  201902               394788
# 5                   도봉구           11350  201704               150732
# 6                   강북구           11410  202008               404501
# 7                   용산구           11620  201407               433658
# 8                   관악구           11140  201710               308087
# 9                  동대문구           11470  201806               447667
# 10                  양천구           11200  201504               559697
# 11                  광진구           11260  201704               379339
# 12                  관악구           11440  201906               431423
# 13                  서초구           11500  201712               234627
# 14                  강남구           11380  201712               451253
# 15                  강남구           11305  201904               542576
# 16                  종로구           11470  201505               442119
# 17                  광진구           11350  202001               226161
# 18                  구로구           11410  201504               126270
# 19                  노원구           11170  201412               233017
# 20                  중랑구           11470  201807               421579
# 21                  도봉구           11380  201408               483473
# 22                  성동구           11545  201805               300410
# 23                  구로구           11320  201505               305785
# 24                  서초구           11440  201704               405271
# 25                  강서구           11410  201712               378199
# 26                  금천구           11440  202007               218929
# 27                  노원구           11710  201409               373252
# 28                  은평구           11170  201404               149524
# 29                  노원구           11680  201708               478019
#
#     세대수(tot_hshld_co)  세대당인구(hshld_popltn_avrg_co)  남자인구수(male_popltn_co)  \
# 0              171426                         2.44                 319062
# 1              186744                         2.12                  75614
# 2               61091                         2.22                 192817
# 3              168865                         2.13                 229690
# 4              168482                         2.52                  61714
# 5               61069                         2.39                  60735
# 6              174263                         2.25                 184053
# 7              173943                         1.85                 252383
# 8              180747                         2.01                 192923
# 9              162606                         2.49                 215440
# 10             109708                         2.36                 237588
# 11             126579                         2.34                 110605
# 12             177247                         2.65                 233214
# 13             144805                         2.46                 172446
# 14              63851                         2.62                 320480
# 15             173142                         2.54                  60139
# 16             248840                         2.19                 157312
# 17             159500                         2.08                 232838
# 18             172505                         2.26                  74025
# 19             243049                         2.40                 117497
# 20             133458                         1.99                 206423
# 21             167301                         2.03                 225186
# 22             269220                         2.64                  74662
# 23             136393                         2.62                 187960
# 24             135147                         2.11                 150937
# 25             185610                         2.46                 157743
# 26             259692                         2.34                 255912
# 27             138984                         2.23                 258407
# 28             229712                         2.57                 167155
# 29             100534                         2.18                 278171
#
#     여자인구수(female_popltn_co)      적재일시(ldadng_dt)
# 0                    118352  2018-01-05 16:52:25
# 1                    116393  2018-12-05 10:20:57
# 2                    307237  2020-11-03 10:50:11
# 3                    204108  2018-01-05 16:52:25
# 4                    146951  2018-01-05 16:52:25
# 5                    199831  2018-01-05 16:52:25
# 6                    172995  2018-01-05 16:52:25
# 7                    198754  2018-01-05 16:52:25
# 8                    245902  2021-01-21 15:43:29
# 9                     64221  2020-07-22 20:11:55
# 10                    75262  2019-04-22 14:53:02
# 11                   174332  2018-01-05 16:52:25
# 12                   192414  2018-01-05 16:52:25
# 13                   332802  2019-09-05 14:06:33
# 14                   177158  2021-06-21 11:02:17
# 15                   243251  2020-11-03 10:50:11
# 16                    61327  2019-04-22 14:53:02
# 17                   158869  2019-03-11 09:30:24
# 18                   284150  2019-08-05 09:45:14
# 19                   298131  2020-11-03 10:50:11
# 20                   182741  2018-01-05 16:52:25
# 21                   204424  2020-07-22 20:11:55
# 22                   197070  2018-12-05 10:20:57
# 23                   177515  2019-03-11 09:30:24
# 24                   148298  2018-11-05 09:53:36
# 25                    78354  2018-01-05 16:52:25
# 26                   285095  2018-01-05 16:52:25
# 27                   204359  2018-01-05 16:52:25
# 28                   162829  2018-01-05 16:52:25
# 29                    61187  2018-01-05 16:52:25

# %%
pd.read_xml('../../csv/2021/202101_expense_list.xml')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pd.read_xml('../../csv/2021/202101_expense_list.xml')
#
# File c:\Users\toqha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\xml.py:1160, in read_xml(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, dtype, converters, parse_dates, encoding, parser, stylesheet, iterparse, compression, storage_options, dtype_backend)
#     888 r"""
#     889 Read XML document into a :class:`~pandas.DataFrame` object.
#     890
#    (...)
#    1156 1      1  <NA>  4.5  False  b 2019-12-31
#    1157 """
#    1158 check_dtype_backend(dtype_backend)
# -> 1160 return _parse(
#    1161     path_or_buffer=path_or_buffer,
#    1162     xpath=xpath,
#    1163     namespaces=namespaces,
#    1164     elems_only=elems_only,
#    1165     attrs_only=attrs_only,
#    1166     names=names,
#    1167     dtype=dtype,
#    1168     converters=converters,
#    1169     parse_dates=parse_dates,
#    1170     encoding=encoding,
#    1171     parser=parser,
#    1172     stylesheet=stylesheet,
#    1173     iterparse=iterparse,
#    1174     compression=compression,
#    1175     storage_options=storage_options,
#    1176     dtype_backend=dtype_backend,
#    1177 )
#
# File c:\Users\toqha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\xml.py:830, in _parse(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, dtype, converters, parse_dates, encoding, parser, stylesheet, iterparse, compression, storage_options, dtype_backend, **kwargs)
#     813         p = _LxmlFrameParser(
#     814             path_or_buffer,
#     815             xpath,
#    (...)
#     827             storage_options,
#     828         )
#     829     else:
# --> 830         raise ImportError("lxml not found, please install or use the etree parser.")
#     832 elif parser == "etree":
#     833     p = _EtreeFrameParser(
#     834         path_or_buffer,
#     835         xpath,
#    (...)
#     847         storage_options,
#     848     )
#
# ImportError: lxml not found, please install or use the etree parser.

# %%
# xml 파일 로드시 모듈 에러 발생시(lxml)
# lxml 모듈을 설치 => pip install lxml
pd.read_xml('../../csv/2021/202101_expense_list.xml')
# Out:
#            nid                                          title  \
# 0     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 1     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 2     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 3     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 4     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# ...        ...                                            ...
# 4873  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4874  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4875  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4876  22241159  2021년 1월 사업소 상수도사업본부 중부수도사업소 요금과 업무추진비 - 부서운영
# 4877  22241159  2021년 1월 사업소 상수도사업본부 중부수도사업소 요금과 업무추진비 - 부서운영
#
#                                              url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# 1     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# 2     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# 3     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# 4     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# ...                                          ...           ...           ...
# 4873  http://opengov.seoul.go.kr/public/22241154         서울시본청        주택건축본부
# 4874  http://opengov.seoul.go.kr/public/22241154         서울시본청        주택건축본부
# 4875  http://opengov.seoul.go.kr/public/22241154         서울시본청        주택건축본부
# 4876  http://opengov.seoul.go.kr/public/22241159           사업소       상수도사업본부
# 4877  http://opengov.seoul.go.kr/public/22241159           사업소       상수도사업본부
#
#      dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr  exec_month  ...  \
# 0          중랑물재생센터          None          None     2021           1  ...
# 1          중랑물재생센터          None          None     2021           1  ...
# 2          중랑물재생센터          None          None     2021           1  ...
# 3          중랑물재생센터          None          None     2021           1  ...
# 4          중랑물재생센터          None          None     2021           1  ...
# ...            ...           ...           ...      ...         ...  ...
# 4873      지역건축안전센터          None          None     2021           1  ...
# 4874      지역건축안전센터          None          None     2021           1  ...
# 4875      지역건축안전센터          None          None     2021           1  ...
# 4876       중부수도사업소           요금과          None     2021           1  ...
# 4877       중부수도사업소           요금과          None     2021           1  ...
#
#       expense_execution  category     dept_nm_full           exec_dt  \
# 0                   NaN      None      중랑물재생센터 관리과  2021-01-25 00:00
# 1                   NaN      None      중랑물재생센터 운영과  2021-01-22 00:00
# 2                   NaN      None    중랑물재생센터 시설보수과  2021-01-21 00:00
# 3                   NaN      None      중랑물재생센터 운영과  2021-01-21 00:00
# 4                   NaN      None      중랑물재생센터 운영과  2021-01-21 00:00
# ...                 ...       ...              ...               ...
# 4873                NaN      None  주택건축본부 지역건축안전센터  2021-01-06 12:33
# 4874                NaN      None  주택건축본부 지역건축안전센터  2021-01-05 18:25
# 4875                NaN      None  주택건축본부 지역건축안전센터  2021-01-04 12:35
# 4876                NaN      None         중부수도 요금과  2021-01-27 15:19
# 4877                NaN      None         중부수도 요금과  2021-01-22 00:00
#
#                      exec_loc                   exec_purpose       target_nm  \
# 0                        None                      소속직원 경조사비        김광옥, 김용성
# 1                         복시루                운영과 다과구매-전출직원선물            None
# 2                         떡시루                       소속직원 송별떡     시설보수과장외 27명
# 3                      서울시청매점                운영과 다과구매-전출직원선물            None
# 4                         복시루                운영과 다과구매-전출직원선물            None
# ...                       ...                            ...             ...
# 4873      곰비임비(중구 세종대로11길 45)  중소형 민간건축공사장 안전대책 관련 간담회 비용 지급  지역건축안전센터장 외 2명
# 4874       본죽&비빔밥(중구 세종대로 80)   소규모 노후 건축물 안전점검 관련 간담회 비용 지급  지역건축안전센터장 외 2명
# 4875     크레이지후라이(중구 서소문로 124)    겨울방학 아르바이트 대학생 격려 간담회 비용 지급  지역건축안전센터장 외 2명
# 4876  가메골에프엔비㈜(중구 남대문시장4길 42)               부서 직원 교육 및 신년간담회      요금과 직원 20명
# 4877        추어탕(중구 다산로 75 3층)                       간부 신년간담회          소장외 3명
#
#      payment_method exec_amount  bimok
# 0                현금      100000   None
# 1                카드       90000   None
# 2                카드       80000   None
# 3              제로페이       48000   None
# 4                카드       75000   None
# ...             ...         ...    ...
# 4873           제로페이       35000   None
# 4874           제로페이       21000   None
# 4875           제로페이       40000   None
# 4876             카드       64000   None
# 4877             카드       36000   None
#
# [4878 rows x 21 columns]

# %% [markdown]
# ### <결측치>
# - 데이터프레임에서 value가 존재하지 않는 경우
# - NaN 표시

# %%
import numpy as np

# %%
data = [
    [1, 2, np.nan, 4, 5],
    [1, np.nan, 3, 4, 5],
    [1, 2, 3, np.nan, 5]
]
cols = ['s1', 's2', 's3', 's4', 's5']
df = pd.DataFrame(data, columns=cols)

# %%
df
# Out:
#    s1   s2   s3   s4  s5
# 0   1  2.0  NaN  4.0   5
# 1   1  NaN  3.0  4.0   5
# 2   1  2.0  3.0  NaN   5

# %%
np.nan == np.nan
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   s1      3 non-null      int64
#  1   s2      2 non-null      float64
#  2   s3      2 non-null      float64
#  3   s4      2 non-null      float64
#  4   s5      3 non-null      int64
# dtypes: float64(3), int64(2)
# memory usage: 248.0 bytes

# %%
# 결측치의 존재 유무 판단 함수 : isna()
# 결측치 => True, 결측치X => False
# 데이터프레임 클래스 안에 있는 isna() 함수 호출
df.isna()
# Out:
#       s1     s2     s3     s4     s5
# 0  False  False   True  False  False
# 1  False   True  False  False  False
# 2  False  False  False   True  False

# %%
df['s2'].isna()
# df['s2']는 Series의 형태 => Series에서도 isna() 사용 가능
# Out:
# 0    False
# 1     True
# 2    False
# Name: s2, dtype: bool

# %%
# 결측치 개수 확인 
# isna() 호출한 뒤 -> 결과 중 True의 개수 확인
sum(df.isna().values)           # 파이썬의 sum
# Out:
# array([0, 1, 1, 1, 0])

# %%
sum(sum(df.isna().values))
# Out:
# np.int64(3)

# %%
# DataFrame 안에 sum 함수는 매개변수 axis 존재
# axis => 0(rows, 행): 각 열 별 NaN 개수 | 1(columns, 열): 각 행 별 NaN 개수
# 기본값은 0(열 기준)
df.isna().sum()             # 클래스 내의 sum() 함수
# Out:
# s1    0
# s2    1
# s3    1
# s4    1
# s5    0
# dtype: int64

# %%
sum(df.isna().sum())
# Out:
# 3

# %%
df.isna().sum(axis=1)
# Out:
# 0    1
# 1    1
# 2    1
# dtype: int64

# %%
# 결측치를 포함하는 행인가? 열인가?
df.isna().any()     # 결측치 포함 열 True 반환
# Out:
# s1    False
# s2     True
# s3     True
# s4     True
# s5    False
# dtype: bool

# %%
df.isna().any(axis=1)       # 결측치 포함 행 True 반환
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
~df.isna().any()
# 결측치X => True
# '~', '-' 연산자 : 스리즈 데이터에서 부정 연산자의 의미로 사용 가능
# Out:
# s1     True
# s2    False
# s3    False
# s4    False
# s5     True
# dtype: bool

# %%
df
# Out:
#    s1   s2   s3   s4  s5
# 0   1  2.0  NaN  4.0   5
# 1   1  NaN  3.0  4.0   5
# 2   1  2.0  3.0  NaN   5

# %%
# 결측치 제거
# 결측치 -> na
# 제거 -> drop
# dropna() 함수 -> axis 매개변수
# axis=0 : 결측치가 포함된 행 제거
# axis=1 : 결측치가 포함된 열 제거
df.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [s1, s2, s3, s4, s5]
# Index: []

# %%
df.dropna(axis=1)
# Out:
#    s1  s5
# 0   1   5
# 1   1   5
# 2   1   5

# %%
df
# Out:
#    s1   s2   s3   s4  s5
# 0   1  2.0  NaN  4.0   5
# 1   1  NaN  3.0  4.0   5
# 2   1  2.0  3.0  NaN   5

# %%
# 결측치에 특정 데이터 대입
# 결측치 -> na
# 결측치들에 값을 채워준다. : fill
# fillna() 함수
    # method 매개변수
        # "ffill" : 결측치를 앞 데이터로 채워준다.
        # "bfill" : 결측치를 뒤 데이터로 채워준다.
        # 앞 데이터, 뒤 데이터가 없다면 NaN 그대로 남아있음

df.fillna(10)
# Out:
#    s1    s2    s3    s4  s5
# 0   1   2.0  10.0   4.0   5
# 1   1  10.0   3.0   4.0   5
# 2   1   2.0   3.0  10.0   5

# %%
df.fillna(method='ffill')
# Out:
# C:\Users\toqha\AppData\Local\Temp\ipykernel_3504\1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#    s1   s2   s3   s4  s5
# 0   1  2.0  NaN  4.0   5
# 1   1  2.0  3.0  4.0   5
# 2   1  2.0  3.0  4.0   5

# %%
df.fillna(method='bfill')
# Out:
# C:\Users\toqha\AppData\Local\Temp\ipykernel_3504\2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#    s1   s2   s3   s4  s5
# 0   1  2.0  3.0  4.0   5
# 1   1  2.0  3.0  4.0   5
# 2   1  2.0  3.0  NaN   5

# %% [markdown]
# ### <데이터프레임의 필터링>
#
# - 데이터프레임명.loc[인덱스의 조건식, 컬럼의 조건식]
#     - 인덱스의 값을 기준으로 필터링
#     - 인덱스가 T/F 필터
#     - 컬럼의 값을 기준으로 필터링
#     - 시작:끝 => 시작값부터 끝값까지
#
# - 데이터프레임명.iloc[인덱스의 위치, 컬럼의 위치]
#     - 인덱스의 위치를 기준으로 필터링
#     - 컬럼의 위치를 기준으로 필터링
#     - 시작:끝 => 시작 위치부터 끝의 전 위치까지
#
# - 데이터프레임명[ 컬럼명 ]
#     - 특정 컬럼의 데이터를 출력
#     - 결과의 타입이 Series(차원축소O)
#
# - 데이터프레임명[ [컬럼명] ]
#     - 특정 컬럼의 데이터를 출력
#     - 결과의 타입이 DataFrame(차원축소X)

# %%
data = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]
idx = [1,4,7]
cols = ['a', 'b', 'c']

df = pd.DataFrame(data, index=idx, columns=cols)

# %%
# df
# Out:
#    a  b  c
# 1  1  2  3
# 4  4  5  6
# 7  7  8  9

# %%
# loc[인덱스의 조건, 컬럼의 조건]
df.loc[4, ]
# Out:
# a    4
# b    5
# c    6
# Name: 4, dtype: int64

# %%
df.loc[ [4], ]
# Out:
#    a  b  c
# 4  4  5  6

# %%
df.loc[ :, 'a']
# 인덱스의 조건은 전체
# Out:
# 1    1
# 4    4
# 7    7
# Name: a, dtype: int64

# %%
df.loc[ : , ['a']]
# Out:
#    a
# 1  1
# 4  4
# 7  7

# %%
# 컬럼 선택 다른 방법
df['b']
# Out:
# 1    2
# 4    5
# 7    8
# Name: b, dtype: int64

# %%
df[['b']]
# Out:
#    b
# 1  2
# 4  5
# 7  8

# %%
# iloc[인덱스의 위치, 컬럼의 위치]
df.iloc[ 1, ]       # 두 번째 위치의 인덱스의 값
# Out:
# a    4
# b    5
# c    6
# Name: 4, dtype: int64

# %%
df.iloc[ [1], ]
# Out:
#    a  b  c
# 4  4  5  6

# %%
df.loc[ :4, ]       # 인덱스=4인 위치까지 출력
# Out:
#    a  b  c
# 1  1  2  3
# 4  4  5  6

# %%
df.iloc[ :2, ]      # 첫 번째 인덱스까지 출력
# Out:
#    a  b  c
# 1  1  2  3
# 4  4  5  6
