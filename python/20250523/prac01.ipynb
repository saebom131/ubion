# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('C:\\ubion\\csv\\AAPL.csv')

# %%
df2 = pd.read_csv('C:/ubion/csv/AAPL.csv')

# %%
df1

# %%
df2

# %%
df1 = pd.read_csv(r'C:\ubion\csv\AAPL.csv')

# %%
df1

# %%
df3 = pd.read_csv('../../csv/AAPL.csv')

# %%
df3
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1980-12-12    0.513393    0.515625    0.513393    0.513393    0.410525
# 1     1980-12-15    0.488839    0.488839    0.486607    0.486607    0.389106
# 2     1980-12-16    0.453125    0.453125    0.450893    0.450893    0.360548
# 3     1980-12-17    0.462054    0.464286    0.462054    0.462054    0.369472
# 4     1980-12-18    0.475446    0.477679    0.475446    0.475446    0.380182
# ...          ...         ...         ...         ...         ...         ...
# 9710  2019-06-18  196.050003  200.289993  195.210007  198.449997  198.449997
# 9711  2019-06-19  199.679993  199.880005  197.309998  197.869995  197.869995
# 9712  2019-06-20  200.369995  200.610001  198.029999  199.460007  199.460007
# 9713  2019-06-21  198.800003  200.850006  198.149994  198.779999  198.779999
# 9714  2019-06-24  198.539993  200.160004  198.169998  199.169998  199.169998
#
#            Volume
# 0     117258400.0
# ...

# %%
df3.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.410525  117258400.0
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.389106   43971200.0
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.360548   26432000.0
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.369472   21610400.0
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.380182   18362400.0

# %%
pd.read_json('../../csv/2021/202101_expense_list.json')
# Out:
#            nid                                          title  \
# 0     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 1     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 2     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 3     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 4     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# ...        ...                                            ...
# 4873  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4874  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4875  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4876  22241159  2021년 1월 사업소 상수도사업본부 중부수도사업소 요금과 업무추진비 - 부서운영
# 4877  22241159  2021년 1월 사업소 상수도사업본부 중부수도사업소 요금과 업무추진비 - 부서운영
#
#                                              url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# ...

# %%
pd.read_excel('../../csv/2021/202101_expense_list.xlsx')
# Out:
#            nid                                          title  \
# 0     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 1     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 2     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 3     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 4     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# ...        ...                                            ...
# 4873  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4874  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4875  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4876  22241159  2021년 1월 사업소 상수도사업본부 중부수도사업소 요금과 업무추진비 - 부서운영
# 4877  22241159  2021년 1월 사업소 상수도사업본부 중부수도사업소 요금과 업무추진비 - 부서운영
#
#                                              url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# ...

# %%
pd.read_csv('../../csv/주민등록.csv', encoding='cp949')
# Out:
#    자치구코드(atdrc_code_se)  자치구명(atdrc_nm)  년월(년월)  총인구수(tot_popltn_co)  \
# 0                   금천구           11110  201907               228755
# 1                  서대문구           11290  201607               153780
# 2                   양천구           11740  201804               594315
# 3                   은평구           11200  202004               345156
# 4                   마포구           11260  201902               394788
# 5                   도봉구           11350  201704               150732
# 6                   강북구           11410  202008               404501
# 7                   용산구           11620  201407               433658
# 8                   관악구           11140  201710               308087
# 9                  동대문구           11470  201806               447667
# 10                  양천구           11200  201504               559697
# 11                  광진구           11260  201704               379339
# 12                  관악구           11440  201906               431423
# ...

# %%
pd.read_xml('../../csv/2021/202101_expense_list.xml')
# Out:
#            nid                                          title  \
# 0     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 1     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 2     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 3     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 4     22249566          2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# ...        ...                                            ...
# 4873  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4874  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4875  22241154    2021년 1월 서울시본청 주택건축본부 지역건축안전센터 업무추진비 - 시책추진
# 4876  22241159  2021년 1월 사업소 상수도사업본부 중부수도사업소 요금과 업무추진비 - 부서운영
# 4877  22241159  2021년 1월 사업소 상수도사업본부 중부수도사업소 요금과 업무추진비 - 부서운영
#
#                                              url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0     http://opengov.seoul.go.kr/public/22249566           사업소         물재생센터
# ...

# %%
data = [
    [1,2,np.nan,4,5],
    [1,np.nan,3,4,5],
    [1,2,3,np.nan,5]
]
cols = ['s1', 's2', 's3', 's4', 's5']

# %%
df = pd.DataFrame(data, columns=cols)

# %%
df
# Out:
#    s1   s2   s3   s4  s5
# 0   1  2.0  NaN  4.0   5
# 1   1  NaN  3.0  4.0   5
# 2   1  2.0  3.0  NaN   5

# %%
np.nan == np.nan
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   s1      3 non-null      int64
#  1   s2      2 non-null      float64
#  2   s3      2 non-null      float64
#  3   s4      2 non-null      float64
#  4   s5      3 non-null      int64
# dtypes: float64(3), int64(2)
# memory usage: 248.0 bytes

# %%
df.isna()
# Out:
#       s1     s2     s3     s4     s5
# 0  False  False   True  False  False
# 1  False   True  False  False  False
# 2  False  False  False   True  False

# %%
df['s2'].isna()
# Out:
# 0    False
# 1     True
# 2    False
# Name: s2, dtype: bool

# %%
sum(df.isna().values)
# Out:
# array([0, 1, 1, 1, 0])

# %%
sum(sum(df.isna().values))
# Out:
# np.int64(3)

# %%
df.isna().values.sum()
# Out:
# np.int64(3)

# %%
df.isna().sum(axis=1)
# Out:
# 0    1
# 1    1
# 2    1
# dtype: int64

# %%
df.isna().sum()
# Out:
# s1    0
# s2    1
# s3    1
# s4    1
# s5    0
# dtype: int64

# %%
df.isna().any()
# Out:
# s1    False
# s2     True
# s3     True
# s4     True
# s5    False
# dtype: bool

# %%
df.isna().any(axis=1)
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
df
# Out:
#    s1   s2   s3   s4  s5
# 0   1  2.0  NaN  4.0   5
# 1   1  NaN  3.0  4.0   5
# 2   1  2.0  3.0  NaN   5

# %%
df.dropna(axis=0)   # 기본값
# Out:
# Empty DataFrame
# Columns: [s1, s2, s3, s4, s5]
# Index: []

# %%
df.dropna(axis=1)
# Out:
#    s1  s5
# 0   1   5
# 1   1   5
# 2   1   5

# %%
df
# Out:
#    s1   s2   s3   s4  s5
# 0   1  2.0  NaN  4.0   5
# 1   1  NaN  3.0  4.0   5
# 2   1  2.0  3.0  NaN   5

# %%
df.fillna(10)
# Out:
#    s1    s2    s3    s4  s5
# 0   1   2.0  10.0   4.0   5
# 1   1  10.0   3.0   4.0   5
# 2   1   2.0   3.0  10.0   5

# %%
df.fillna(method='ffill')
# Out:
# C:\Users\toqha\AppData\Local\Temp\ipykernel_17236\1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#    s1   s2   s3   s4  s5
# 0   1  2.0  NaN  4.0   5
# 1   1  2.0  3.0  4.0   5
# 2   1  2.0  3.0  4.0   5

# %%
df.fillna(method='bfill')
# Out:
# C:\Users\toqha\AppData\Local\Temp\ipykernel_17236\2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#    s1   s2   s3   s4  s5
# 0   1  2.0  3.0  4.0   5
# 1   1  2.0  3.0  4.0   5
# 2   1  2.0  3.0  NaN   5

# %%
data = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]
idx = [1,4,7]
cols = ['a','b','c']

# %%
df = pd.DataFrame(data, index=idx, columns=cols)

# %%
df
# Out:
#    a  b  c
# 1  1  2  3
# 4  4  5  6
# 7  7  8  9

# %%
df.loc[4]
# Out:
# a    4
# b    5
# c    6
# Name: 4, dtype: int64

# %%
df.loc[4, 'a']
# Out:
# np.int64(4)

# %%
df.iloc[2, ]
# Out:
# a    7
# b    8
# c    9
# Name: 7, dtype: int64

# %%
df.iloc[-1,-1]
# Out:
# np.int64(9)

# %%
df.loc[[4]]
# Out:
#    a  b  c
# 4  4  5  6

# %%
type(df.iloc[[1]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[ :,['a']]
# Out:
#    a
# 1  1
# 4  4
# 7  7

# %%
df.iloc[:, :]
# Out:
#    a  b  c
# 1  1  2  3
# 4  4  5  6
# 7  7  8  9
