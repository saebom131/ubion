# %%
import pandas as pd
from invest import Quant

# %%
# Quant class 생성
df = pd.read_csv('../csv/SLV.csv')

# %%
quant = Quant(df)

# %%
quant.buyandhold()
# Out:
# 바이앤홀드 전략으로 최종 수익률은 0.8376610562971583
# (            Adj Close       rtn   acc_rtn
#  Date
#  2010-01-04  17.230000  1.000000  1.000000
#  2010-01-05  17.510000  1.016251  1.016251
#  2010-01-06  17.860001  1.019989  1.036564
#  2010-01-07  17.889999  1.001680  1.038305
#  2010-01-08  18.150000  1.014533  1.053395
#  ...               ...       ...       ...
#  2019-06-18  14.050000  1.010791  0.815438
#  2019-06-19  14.170000  1.008541  0.822403
#  2019-06-20  14.450000  1.019760  0.838654
#  2019-06-21  14.360000  0.993772  0.833430
#  2019-06-24  14.432900  1.005077  0.837661
#
#  [2384 rows x 3 columns],
#  np.float64(0.8376610562971583))

# %%
boll_df, boll_rtn = quant.bollinger(_cnt=10)
# Out:
# c:\ubion\python\invest\__init__.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   trade_df['trade'].fillna('', inplace=True)
# c:\ubion\python\invest\bollinger.py:97: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.970122964264792' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[idx, 'rtn'] = rtn
# 매수일: 2010-01-21 00:00:00, 매수가: 17.07
# 매도일: 2010-03-02 00:00:00, 매도가: 16.559999, 수익률: 0.970122964264792
# 매수일: 2010-05-05 00:00:00, 매수가: 17.110001
# 매도일: 2010-06-18 00:00:00, 매도가: 18.75, 수익률: 1.095850315847439
# 매수일: 2010-07-01 00:00:00, 매수가: 17.440001
# 매도일: 2010-08-25 00:00:00, 매도가: 18.540001, 수익률: 1.0630733908788195
# 매수일: 2011-01-20 00:00:00, 매수가: 26.85
# 매도일: 2011-02-18 00:00:00, 매도가: 31.790001, 수익률: 1.1839851396648045
# 매수일: 2011-05-04 00:00:00, 매수가: 38.27
# 매도일: 2011-05-24 00:00:00, 매도가: 35.77, 수익률: 0.9346746799059316
# 매수일: 2011-06-27 00:00:00, 매수가: 32.630001
# 매도일: 2011-08-19 00:00:00, 매도가: 41.68, 수익률: 1.2773520907952163
# 매수일: 2011-09-22 00:00:00, 매수가: 34.919998
# 매도일: 2011-10-27 00:00:00, 매도가: 34.099998, 수익률: 0.9765177535233536
# 매수일: 2011-11-17 00:00:00, 매수가: 30.639999
# 매도일: 2012-01-20 00:00:00, 매도가: 31.219999, 수익률: 1.0189295045342528
# 매수일: 2012-04-23 00:00:00, 매수가: 29.969999
# 매도일: 2012-06-06 00:00:00, 매도가: 28.51, 수익률: 0.9512846496925141
# 매수일: 2012-06-20 00:00:00, 매수가: 27.26
# 매도일: 2012-07-27 00:00:00, 매도가: 26.959999, 수익률: 0.9889948275862068
# 매수일: 2012-10-15 00:00:00, 매수가: 31.66
# 매도일: 2012-11-23 00:00:00, 매도가: 32.98, 수익률: 1.041692987997473
# 매수일: 2012-12-20 00:00:00, 매수가: 29.0
# 매도일: 2013-08-08 00:00:00, 매도가: 19.6, 수익률: 0.6758620689655173
# 매수일: 2013-09-12 00:00:00, 매수가: 21.059999
# 매도일: 2013-10-07 00:00:00, 매도가: 21.530001, 수익률: 1.0223172850103173
# 매수일: 2013-11-13 00:00:00, 매수가: 19.780001
# 매도일: 2014-02-14 00:00:00, 매도가: 20.65, 수익률: 1.0439837692627012
# 매수일: 2014-04-15 00:00:00, 매수가: 18.879999
# 매도일: 2014-06-12 00:00:00, 매도가: 18.76, 수익률: 0.9936441204260658
# 매수일: 2014-08-05 00:00:00, 매수가: 19.049999
# 매도일: 2014-12-30 00:00:00, 매도가: 15.58, 수익률: 0.817847811960515
# 매수일: 2015-03-06 00:00:00, 매수가: 15.19
# 매도일: 2015-03-20 00:00:00, 매도가: 16.0, 수익률: 1.0533245556287032
# 매수일: 2015-04-09 00:00:00, 매수가: 15.51
# 매도일: 2015-05-13 00:00:00, 매도가: 16.35, 수익률: 1.0541586073500968
# 매수일: 2015-06-04 00:00:00, 매수가: 15.48
# 매도일: 2015-08-10 00:00:00, 매도가: 14.54, 수익률: 0.9392764857881136
# 매수일: 2015-08-26 00:00:00, 매수가: 13.56
# 매도일: 2015-09-17 00:00:00, 매도가: 14.42, 수익률: 1.0634218289085546
# 매수일: 2015-10-29 00:00:00, 매수가: 14.88
# 매도일: 2015-12-04 00:00:00, 매도가: 13.87, 수익률: 0.9321236559139784
# 매수일: 2016-02-26 00:00:00, 매수가: 14.02
# 매도일: 2016-03-17 00:00:00, 매도가: 15.16, 수익률: 1.0813124108416547
# 매수일: 2016-05-19 00:00:00, 매수가: 15.67
# 매도일: 2016-06-08 00:00:00, 매도가: 16.209999, 수익률: 1.0344606892150605
# 매수일: 2016-07-20 00:00:00, 매수가: 18.42
# 매도일: 2016-09-02 00:00:00, 매도가: 18.440001, 수익률: 1.0010858306188923
# 매수일: 2016-10-04 00:00:00, 매수가: 16.940001
# 매도일: 2016-11-01 00:00:00, 매도가: 17.41, 수익률: 1.0277449216207248
# 매수일: 2016-11-11 00:00:00, 매수가: 16.469999
# 매도일: 2016-12-07 00:00:00, 매도가: 16.23, 수익률: 0.9854281108335221
# 매수일: 2016-12-15 00:00:00, 매수가: 15.18
# 매도일: 2017-01-17 00:00:00, 매도가: 16.280001, 수익률: 1.0724638339920949
# 매수일: 2017-04-07 00:00:00, 매수가: 17.030001
# 매도일: 2017-05-16 00:00:00, 매도가: 15.93, 수익률: 0.935408048419962
# 매수일: 2017-06-12 00:00:00, 매수가: 16.040001
# 매도일: 2017-08-28 00:00:00, 매도가: 16.5, 수익률: 1.0286782401073415
# 매수일: 2017-09-18 00:00:00, 매수가: 16.27
# 매도일: 2017-10-10 00:00:00, 매도가: 16.15, 수익률: 0.9926244622003687
# 매수일: 2017-11-29 00:00:00, 매수가: 15.64
# 매도일: 2017-12-27 00:00:00, 매도가: 15.73, 수익률: 1.0057544757033248
# 매수일: 2018-02-02 00:00:00, 매수가: 15.66
# 매도일: 2018-04-18 00:00:00, 매도가: 16.18, 수익률: 1.0332056194125159
# 매수일: 2018-08-13 00:00:00, 매수가: 14.1
# 매도일: 2018-09-25 00:00:00, 매도가: 13.59, 수익률: 0.9638297872340426
# 매수일: 2018-10-29 00:00:00, 매수가: 13.59
# 매도일: 2018-12-26 00:00:00, 매도가: 14.11, 수익률: 1.0382634289919057
# 매수일: 2019-01-18 00:00:00, 매수가: 14.37
# 매도일: 2019-02-19 00:00:00, 매도가: 15.02, 수익률: 1.0452331245650661
# 매수일: 2019-03-01 00:00:00, 매수가: 14.2
# 매도일: 2019-06-03 00:00:00, 매도가: 13.87, 수익률: 0.9767605633802817
# 볼린저밴드 전략으로 최종 수익률은 1.1643719667344417

# %%
quant.halloween(month=10)
# Out:
# 할로윈 전략으로 최종 수익률은 1.3860768566086354
# c:\ubion\python\invest\halloween.py:52: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6983833718244805' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   result.iloc[idx, -1] = rtn
# (            Adj Close       rtn   acc_rtn
#  Date
#  2010-10-01  21.650000  1.000000  1.000000
#  2011-03-31  36.770000  1.698383  1.698383
#  2011-10-03  29.490000  1.000000  1.698383
#  2012-03-30  31.379999  1.064089  1.807232
#  2012-10-01  33.650002  1.000000  1.807232
#  2013-03-28  27.420000  0.814859  1.472639
#  2013-10-01  20.410000  1.000000  1.472639
#  2014-03-31  19.040001  0.932876  1.373790
#  2014-10-01  16.480000  1.000000  1.373790
#  2015-03-31  15.930000  0.966626  1.327941
#  2015-10-01  13.900000  1.000000  1.327941
#  2016-03-31  14.680000  1.056115  1.402459
#  2016-10-03  17.870001  1.000000  1.402459
#  2017-03-31  17.250000  0.965305  1.353800
#  2017-10-02  15.670000  1.000000  1.353800
#  2018-03-29  15.410000  0.983408  1.331338
#  2018-10-01  13.620000  1.000000  1.331338
#  2019-03-29  14.180000  1.041116  1.386077,
#  np.float64(1.3860768566086354))

# %%
quant.momentum(_momentum=6)
# Out:
# c:\ubion\python\invest\momentum.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BF1'] = df.shift(1)[col].fillna(0)
# c:\ubion\python\invest\momentum.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BF2'] = df.shift(_momentum)[col].fillna(0)
# 매수일: 2010-01-29 00:00:00, 매수가: 15.9
# 매도일: 2010-03-31 00:00:00, 매도가: 17.139999, 수익률: 1.077987358490566
# 매수일: 2010-04-30 00:00:00, 매수가: 18.26
# 매도일: 2011-10-31 00:00:00, 매도가: 33.439999, 수익률: 1.8313252464403065
# 매수일: 2012-03-30 00:00:00, 매수가: 31.379999
# c:\ubion\python\invest\momentum.py:89: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.077987358490566' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[idx, 'rtn'] = rtn
# 매도일: 2012-04-30 00:00:00, 매도가: 30.110001, 수익률: 0.9595284244591594
# 매수일: 2012-06-29 00:00:00, 매수가: 26.65
# 매도일: 2012-07-31 00:00:00, 매도가: 27.120001, 수익률: 1.0176360600375234
# 매수일: 2012-10-31 00:00:00, 매수가: 31.27
# 매도일: 2013-02-28 00:00:00, 매도가: 27.540001, 수익률: 0.8807163735209466
# 매수일: 2013-12-31 00:00:00, 매수가: 18.709999
# 매도일: 2014-01-31 00:00:00, 매도가: 18.450001, 수익률: 0.9861037940194438
# 매수일: 2014-07-31 00:00:00, 매수가: 19.58
# 매도일: 2014-08-29 00:00:00, 매도가: 18.709999, 수익률: 0.9555668539325843
# 매수일: 2015-04-30 00:00:00, 매수가: 15.43
# 매도일: 2015-07-31 00:00:00, 매도가: 14.08, 수익률: 0.9125081011017498
# 매수일: 2016-03-31 00:00:00, 매수가: 14.68
# 매도일: 2016-04-29 00:00:00, 매도가: 16.98, 수익률: 1.1566757493188011
# 매수일: 2016-05-31 00:00:00, 매수가: 15.19
# 매도일: 2016-12-30 00:00:00, 매도가: 15.11, 수익률: 0.9947333772218565
# 매수일: 2017-04-28 00:00:00, 매수가: 16.299999
# 매도일: 2017-07-31 00:00:00, 매도가: 15.9, 수익률: 0.9754601825435695
# 매수일: 2018-01-31 00:00:00, 매수가: 16.35
# 매도일: 2018-02-28 00:00:00, 매도가: 15.46, 수익률: 0.945565749235474
# 매수일: 2019-02-28 00:00:00, 매수가: 14.63
# 매도일: 2019-06-24 00:00:00, 매도가: 14.4329, 수익률: 0.9865276828434723
# 모멘텀 전략으로 최종 수익률은 1.5283220009421532
# (            Adj Close   STD-YM trade       rtn   acc_rtn
#  Date
#  2006-04-28    13.8120  2006-04        1.000000  1.000000
#  2006-05-01    13.8700  2006-05        1.000000  1.000000
#  2006-05-02    14.3650  2006-05        1.000000  1.000000
#  2006-05-03    13.9250  2006-05        1.000000  1.000000
#  2006-05-04    14.0000  2006-05        1.000000  1.000000
#  ...               ...      ...   ...       ...       ...
#  2019-06-18    14.0500  2019-06   buy  1.000000  1.549193
#  2019-06-19    14.1700  2019-06   buy  1.000000  1.549193
#  2019-06-20    14.4500  2019-06   buy  1.000000  1.549193
#  2019-06-21    14.3600  2019-06   buy  1.000000  1.549193
#  2019-06-24    14.4329  2019-06        0.986528  1.528322
#
#  [3311 rows x 5 columns],
#  np.float64(1.5283220009421532))
