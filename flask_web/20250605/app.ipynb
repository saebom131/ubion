# %%
import pandas as pd

# %%
corona = pd.read_csv("./data/corona.csv", index_col=0)

# %%
corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 820 entries, 0 to 819
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   createDt    820 non-null    object
#  1   deathCnt    820 non-null    int64
#  2   decideCnt   820 non-null    int64
#  3   seq         820 non-null    int64
#  4   stateDt     820 non-null    int64
#  5   stateTime   820 non-null    object
#  6   updateDt    817 non-null    object
#  7   accExamCnt  692 non-null    float64
#  8   accDefRate  623 non-null    float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 64.1+ KB

# %%
corona.head(2)
# Out:
#                   createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0  2022-06-08 09:09:05.982     24305   18188200  904  20220608     00:00
# 1  2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
#
#                   updateDt  accExamCnt  accDefRate
# 0                      NaN         NaN         NaN
# 1  2022-06-08 09:10:36.846         NaN         NaN

# %%
corona.sort_values(['stateDt'], inplace=True)
corona.head(2)
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
#
#                    updateDt  accExamCnt  accDefRate
# 819  2021-10-07 10:30:51.51    210144.0    3.919308
# 818  2021-10-07 10:30:51.51    222395.0    3.804175

# %%
corona['일일확진자'] = (corona['decideCnt'] - corona['decideCnt'].shift(1)).fillna(0)

# %%
corona.head(3)
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
#
#                    updateDt  accExamCnt  accDefRate  일일확진자
# 819  2021-10-07 10:30:51.51    210144.0    3.919308    0.0
# 818  2021-10-07 10:30:51.51    222395.0    3.804175  242.0
# 817  2021-10-07 10:30:51.51    234998.0    3.621744  114.0

# %%
corona['일일사망자'] = corona['deathCnt'].diff(1).fillna(0)

# %%
corona.head(3)
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
#
#                    updateDt  accExamCnt  accDefRate  일일확진자  일일사망자
# 819  2021-10-07 10:30:51.51    210144.0    3.919308    0.0    0.0
# 818  2021-10-07 10:30:51.51    222395.0    3.804175  242.0    6.0
# 817  2021-10-07 10:30:51.51    234998.0    3.621744  114.0    6.0

# %%
df = corona[ ['stateDt', '일일확진자', '일일사망자', 'stateTime', 'updateDt']]
df.head(3)
# Out:
#       stateDt  일일확진자  일일사망자 stateTime                updateDt
# 819  20200310    0.0    0.0     00:00  2021-10-07 10:30:51.51
# 818  20200311  242.0    6.0     00:00  2021-10-07 10:30:51.51
# 817  20200312  114.0    6.0     00:00  2021-10-07 10:30:51.51

# %%
df.tail(3)
# Out:
#     stateDt    일일확진자  일일사망자 stateTime                 updateDt
# 2  20220606   5022.0   21.0     00:00  2022-06-08 09:10:50.441
# 1  20220607   6172.0   20.0     00:00  2022-06-08 09:10:36.846
# 0  20220608  13358.0    6.0     00:00                      NaN

# %%
date = df.iloc[-1, 0]
decide = df.iloc[-1, 1]
death = df.iloc[-1, 2]

# %%
print(f"최근일 : {date}, 일일확진자수 : {decide}, 일일사망자수 : {death}")
# Out:
# 최근일 : 20220608, 일일확진자수 : 13358.0, 일일사망자수 : 6.0

# %%
col_list = list(df.columns)
col_list
# Out:
# ['stateDt', '일일확진자', '일일사망자', 'stateTime', 'updateDt']

# %%
dict_data = df.to_dict(orient='records')
dict_data
# Out:
# [{'stateDt': 20200310,
#   '일일확진자': 0.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200311,
#   '일일확진자': 242.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200312,
#   '일일확진자': 114.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200313,
#   '일일확진자': 110.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200314,
#   '일일확진자': 107.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200315,
#   '일일확진자': 76.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200316,
#   '일일확진자': 74.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200317,
#   '일일확진자': 84.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200318,
#   '일일확진자': 93.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200319,
#   '일일확진자': 152.0,
#   '일일사망자': 7.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200320,
#   '일일확진자': 87.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200321,
#   '일일확진자': 147.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200322,
#   '일일확진자': 98.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200323,
#   '일일확진자': 64.0,
#   '일일사망자': 7.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200324,
#   '일일확진자': 76.0,
#   '일일사망자': 9.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200325,
#   '일일확진자': 100.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200326,
#   '일일확진자': 104.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200327,
#   '일일확진자': 91.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200328,
#   '일일확진자': 146.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200329,
#   '일일확진자': 105.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200330,
#   '일일확진자': 78.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200331,
#   '일일확진자': 125.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200401,
#   '일일확진자': 101.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200402,
#   '일일확진자': 89.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200403,
#   '일일확진자': 86.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200404,
#   '일일확진자': 94.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200405,
#   '일일확진자': 81.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200406,
#   '일일확진자': 47.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200407,
#   '일일확진자': 47.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200408,
#   '일일확진자': 53.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200409,
#   '일일확진자': 39.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200410,
#   '일일확진자': 27.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200411,
#   '일일확진자': 30.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200412,
#   '일일확진자': 32.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200413,
#   '일일확진자': 25.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200414,
#   '일일확진자': 27.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200415,
#   '일일확진자': 27.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200416,
#   '일일확진자': 22.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200417,
#   '일일확진자': 22.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200418,
#   '일일확진자': 18.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200419,
#   '일일확진자': 8.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200420,
#   '일일확진자': 13.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200421,
#   '일일확진자': 9.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200422,
#   '일일확진자': 11.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200423,
#   '일일확진자': 8.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200424,
#   '일일확진자': 6.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200425,
#   '일일확진자': 10.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200426,
#   '일일확진자': 10.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200427,
#   '일일확진자': 10.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200428,
#   '일일확진자': 14.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200429,
#   '일일확진자': 9.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200430,
#   '일일확진자': 4.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200501,
#   '일일확진자': 9.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200502,
#   '일일확진자': 6.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200503,
#   '일일확진자': 13.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200504,
#   '일일확진자': 8.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200505,
#   '일일확진자': 3.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200506,
#   '일일확진자': 2.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200507,
#   '일일확진자': 4.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200508,
#   '일일확진자': 12.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200509,
#   '일일확진자': 18.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200510,
#   '일일확진자': 34.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200511,
#   '일일확진자': 35.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200512,
#   '일일확진자': 27.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200513,
#   '일일확진자': 26.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200515,
#   '일일확진자': 56.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200516,
#   '일일확진자': 19.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200517,
#   '일일확진자': 13.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200518,
#   '일일확진자': 15.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200519,
#   '일일확진자': 13.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200520,
#   '일일확진자': 32.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200521,
#   '일일확진자': 12.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200522,
#   '일일확진자': 20.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200523,
#   '일일확진자': 23.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200524,
#   '일일확진자': 25.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200525,
#   '일일확진자': 16.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200526,
#   '일일확진자': 19.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200527,
#   '일일확진자': 40.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200528,
#   '일일확진자': 79.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200529,
#   '일일확진자': 58.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200530,
#   '일일확진자': 39.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200531,
#   '일일확진자': 27.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200601,
#   '일일확진자': 35.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200602,
#   '일일확진자': 38.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200603,
#   '일일확진자': 49.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200604,
#   '일일확진자': 39.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200605,
#   '일일확진자': 39.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200606,
#   '일일확진자': 51.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200607,
#   '일일확진자': 57.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200608,
#   '일일확진자': 37.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200609,
#   '일일확진자': 38.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200610,
#   '일일확진자': 50.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200611,
#   '일일확진자': 45.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200612,
#   '일일확진자': 56.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200613,
#   '일일확진자': 48.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200614,
#   '일일확진자': 34.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200615,
#   '일일확진자': 37.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200616,
#   '일일확진자': 34.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200617,
#   '일일확진자': 43.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200618,
#   '일일확진자': 59.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200619,
#   '일일확진자': 49.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200620,
#   '일일확진자': 67.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200621,
#   '일일확진자': 48.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200622,
#   '일일확진자': 17.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200623,
#   '일일확진자': 46.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200624,
#   '일일확진자': 51.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200625,
#   '일일확진자': 28.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200626,
#   '일일확진자': 39.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200627,
#   '일일확진자': 51.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200628,
#   '일일확진자': 62.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200629,
#   '일일확진자': 42.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200630,
#   '일일확진자': 42.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200701,
#   '일일확진자': 51.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200702,
#   '일일확진자': 54.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200703,
#   '일일확진자': 61.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200704,
#   '일일확진자': 63.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200705,
#   '일일확진자': 61.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200706,
#   '일일확진자': 48.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200707,
#   '일일확진자': 44.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200708,
#   '일일확진자': 62.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200709,
#   '일일확진자': 50.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200710,
#   '일일확진자': 45.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200711,
#   '일일확진자': 35.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200712,
#   '일일확진자': 44.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200713,
#   '일일확진자': 62.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200714,
#   '일일확진자': 33.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200715,
#   '일일확진자': 39.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200716,
#   '일일확진자': 61.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200717,
#   '일일확진자': 60.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200718,
#   '일일확진자': 39.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200719,
#   '일일확진자': 34.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200720,
#   '일일확진자': 26.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200721,
#   '일일확진자': 45.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200722,
#   '일일확진자': 63.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200723,
#   '일일확진자': 59.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200724,
#   '일일확진자': 41.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200725,
#   '일일확진자': 113.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200726,
#   '일일확진자': 58.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200727,
#   '일일확진자': 25.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200728,
#   '일일확진자': 28.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200729,
#   '일일확진자': 48.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200730,
#   '일일확진자': 18.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200731,
#   '일일확진자': 36.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200801,
#   '일일확진자': 31.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200802,
#   '일일확진자': 30.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200803,
#   '일일확진자': 23.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200804,
#   '일일확진자': 34.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200805,
#   '일일확진자': 33.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200806,
#   '일일확진자': 43.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200807,
#   '일일확진자': 20.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200808,
#   '일일확진자': 43.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200809,
#   '일일확진자': 36.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200810,
#   '일일확진자': 28.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200811,
#   '일일확진자': 34.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200812,
#   '일일확진자': 54.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200813,
#   '일일확진자': 56.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200814,
#   '일일확진자': 103.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200815,
#   '일일확진자': 166.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200816,
#   '일일확진자': 279.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200817,
#   '일일확진자': 197.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200818,
#   '일일확진자': 246.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200819,
#   '일일확진자': 297.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200820,
#   '일일확진자': 288.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200821,
#   '일일확진자': 324.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200822,
#   '일일확진자': 332.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200823,
#   '일일확진자': 396.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200824,
#   '일일확진자': 266.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200825,
#   '일일확진자': 280.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200826,
#   '일일확진자': 320.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200827,
#   '일일확진자': 441.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200828,
#   '일일확진자': 371.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200829,
#   '일일확진자': 323.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200830,
#   '일일확진자': 299.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200831,
#   '일일확진자': 248.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200901,
#   '일일확진자': 235.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200902,
#   '일일확진자': 267.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200903,
#   '일일확진자': 195.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200904,
#   '일일확진자': 198.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200905,
#   '일일확진자': 168.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200906,
#   '일일확진자': 167.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200907,
#   '일일확진자': 119.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200908,
#   '일일확진자': 136.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200909,
#   '일일확진자': 156.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200910,
#   '일일확진자': 155.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200911,
#   '일일확진자': 176.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200912,
#   '일일확진자': 136.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200913,
#   '일일확진자': 121.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200914,
#   '일일확진자': 109.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200915,
#   '일일확진자': 106.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200916,
#   '일일확진자': 113.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200917,
#   '일일확진자': 153.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200918,
#   '일일확진자': 126.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200919,
#   '일일확진자': 110.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200920,
#   '일일확진자': 82.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200921,
#   '일일확진자': 70.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200922,
#   '일일확진자': 61.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200923,
#   '일일확진자': 110.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200924,
#   '일일확진자': 125.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200925,
#   '일일확진자': 114.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200926,
#   '일일확진자': 61.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200927,
#   '일일확진자': 95.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200928,
#   '일일확진자': 50.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200929,
#   '일일확진자': 38.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20200930,
#   '일일확진자': 113.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201001,
#   '일일확진자': 77.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201002,
#   '일일확진자': 63.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201003,
#   '일일확진자': 75.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201004,
#   '일일확진자': 64.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201005,
#   '일일확진자': 73.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201006,
#   '일일확진자': 75.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201007,
#   '일일확진자': 114.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201008,
#   '일일확진자': 69.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201009,
#   '일일확진자': 54.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201010,
#   '일일확진자': 72.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201011,
#   '일일확진자': 58.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201012,
#   '일일확진자': 98.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201013,
#   '일일확진자': 91.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201014,
#   '일일확진자': 84.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201015,
#   '일일확진자': 110.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201016,
#   '일일확진자': 47.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201017,
#   '일일확진자': 73.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201018,
#   '일일확진자': 91.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201019,
#   '일일확진자': 76.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201020,
#   '일일확진자': 58.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201021,
#   '일일확진자': 89.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201022,
#   '일일확진자': 121.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201023,
#   '일일확진자': 155.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201024,
#   '일일확진자': 77.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201025,
#   '일일확진자': 61.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201026,
#   '일일확진자': 119.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201027,
#   '일일확진자': 88.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201028,
#   '일일확진자': 103.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201029,
#   '일일확진자': 125.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201030,
#   '일일확진자': 113.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201031,
#   '일일확진자': 127.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201101,
#   '일일확진자': 124.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201102,
#   '일일확진자': 97.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201103,
#   '일일확진자': 75.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201104,
#   '일일확진자': 117.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201105,
#   '일일확진자': 125.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201106,
#   '일일확진자': 145.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201107,
#   '일일확진자': 89.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201108,
#   '일일확진자': 143.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201109,
#   '일일확진자': 126.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201110,
#   '일일확진자': 100.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201111,
#   '일일확진자': 145.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201112,
#   '일일확진자': 143.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201113,
#   '일일확진자': 191.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201114,
#   '일일확진자': 205.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201115,
#   '일일확진자': 208.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201116,
#   '일일확진자': 222.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201117,
#   '일일확진자': 230.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201118,
#   '일일확진자': 285.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201119,
#   '일일확진자': 325.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201120,
#   '일일확진자': 348.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201121,
#   '일일확진자': 386.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201122,
#   '일일확진자': 330.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201123,
#   '일일확진자': 271.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201124,
#   '일일확진자': 349.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201125,
#   '일일확진자': 382.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201126,
#   '일일확진자': 581.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201127,
#   '일일확진자': 555.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201128,
#   '일일확진자': 503.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201129,
#   '일일확진자': 450.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201130,
#   '일일확진자': 438.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201201,
#   '일일확진자': 451.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201202,
#   '일일확진자': 511.0,
#   '일일사망자': 0.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201203,
#   '일일확진자': 540.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201204,
#   '일일확진자': 628.0,
#   '일일사망자': 7.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201205,
#   '일일확진자': 577.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201206,
#   '일일확진자': 631.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201207,
#   '일일확진자': 615.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201208,
#   '일일확진자': 587.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201209,
#   '일일확진자': 670.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201210,
#   '일일확진자': 680.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201211,
#   '일일확진자': 689.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201212,
#   '일일확진자': 950.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201213,
#   '일일확진자': 1030.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201214,
#   '일일확진자': 718.0,
#   '일일사망자': 7.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201215,
#   '일일확진자': 880.0,
#   '일일사망자': 13.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201216,
#   '일일확진자': 1078.0,
#   '일일사망자': 12.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201217,
#   '일일확진자': 1014.0,
#   '일일사망자': 22.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201218,
#   '일일확진자': 1064.0,
#   '일일사망자': 11.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201219,
#   '일일확진자': 1045.0,
#   '일일사망자': 14.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201220,
#   '일일확진자': 1096.0,
#   '일일사망자': 15.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201221,
#   '일일확진자': 924.0,
#   '일일사망자': 24.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201222,
#   '일일확진자': 866.0,
#   '일일사망자': 24.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201223,
#   '일일확진자': 1090.0,
#   '일일사망자': 17.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201224,
#   '일일확진자': 985.0,
#   '일일사망자': 17.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201225,
#   '일일확진자': 1240.0,
#   '일일사망자': 17.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201226,
#   '일일확진자': 1131.0,
#   '일일사망자': 20.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201227,
#   '일일확진자': 970.0,
#   '일일사망자': 15.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201228,
#   '일일확진자': 806.0,
#   '일일사망자': 11.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201229,
#   '일일확진자': 1044.0,
#   '일일사망자': 40.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201230,
#   '일일확진자': 1050.0,
#   '일일사망자': 20.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20201231,
#   '일일확진자': 967.0,
#   '일일사망자': 21.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210101,
#   '일일확진자': 1027.0,
#   '일일사망자': 17.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210102,
#   '일일확진자': 820.0,
#   '일일사망자': 25.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210103,
#   '일일확진자': 657.0,
#   '일일사망자': 20.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210104,
#   '일일확진자': 1020.0,
#   '일일사망자': 19.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210105,
#   '일일확진자': 714.0,
#   '일일사망자': 26.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210106,
#   '일일확진자': 838.0,
#   '일일사망자': 20.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210107,
#   '일일확진자': 869.0,
#   '일일사망자': 19.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210108,
#   '일일확진자': 674.0,
#   '일일사망자': 35.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210109,
#   '일일확진자': 641.0,
#   '일일사망자': 19.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210110,
#   '일일확진자': 657.0,
#   '일일사망자': 25.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210111,
#   '일일확진자': 451.0,
#   '일일사망자': 15.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210112,
#   '일일확진자': 537.0,
#   '일일사망자': 25.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210113,
#   '일일확진자': 561.0,
#   '일일사망자': 20.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210114,
#   '일일확진자': 524.0,
#   '일일사망자': 10.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210115,
#   '일일확진자': 512.0,
#   '일일사망자': 22.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210116,
#   '일일확진자': 580.0,
#   '일일사망자': 19.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210117,
#   '일일확진자': 520.0,
#   '일일사망자': 13.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210118,
#   '일일확진자': 389.0,
#   '일일사망자': 15.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210119,
#   '일일확진자': 386.0,
#   '일일사망자': 19.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210120,
#   '일일확진자': 404.0,
#   '일일사망자': 17.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210121,
#   '일일확진자': 400.0,
#   '일일사망자': 16.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210122,
#   '일일확진자': 346.0,
#   '일일사망자': 12.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210123,
#   '일일확진자': 431.0,
#   '일일사망자': 9.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210124,
#   '일일확진자': 392.0,
#   '일일사망자': 12.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210125,
#   '일일확진자': 437.0,
#   '일일사망자': 11.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210126,
#   '일일확진자': 349.0,
#   '일일사망자': 11.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210127,
#   '일일확진자': 559.0,
#   '일일사망자': 7.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210128,
#   '일일확진자': 497.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210129,
#   '일일확진자': 469.0,
#   '일일사망자': 13.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210130,
#   '일일확진자': 456.0,
#   '일일사망자': 15.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210131,
#   '일일확진자': 354.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210201,
#   '일일확진자': 305.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210202,
#   '일일확진자': 336.0,
#   '일일사망자': 10.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210203,
#   '일일확진자': 467.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210204,
#   '일일확진자': 451.0,
#   '일일사망자': 7.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210205,
#   '일일확진자': 370.0,
#   '일일사망자': 11.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210206,
#   '일일확진자': 390.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210207,
#   '일일확진자': 371.0,
#   '일일사망자': 7.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210208,
#   '일일확진자': 288.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210209,
#   '일일확진자': 303.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210210,
#   '일일확진자': 444.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210211,
#   '일일확진자': 504.0,
#   '일일사망자': 10.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210212,
#   '일일확진자': 403.0,
#   '일일사망자': 11.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210213,
#   '일일확진자': 362.0,
#   '일일사망자': 7.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210214,
#   '일일확진자': 326.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210215,
#   '일일확진자': 343.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210216,
#   '일일확진자': 457.0,
#   '일일사망자': 7.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210217,
#   '일일확진자': 621.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210218,
#   '일일확진자': 621.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210219,
#   '일일확진자': 561.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210220,
#   '일일확진자': 448.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210221,
#   '일일확진자': 416.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210222,
#   '일일확진자': 332.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210223,
#   '일일확진자': 356.0,
#   '일일사망자': 11.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210224,
#   '일일확진자': 440.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210225,
#   '일일확진자': 395.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210226,
#   '일일확진자': 387.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210227,
#   '일일확진자': 415.0,
#   '일일사망자': 10.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210228,
#   '일일확진자': 355.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210301,
#   '일일확진자': 355.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210302,
#   '일일확진자': 344.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210303,
#   '일일확진자': 444.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210304,
#   '일일확진자': 424.0,
#   '일일사망자': 7.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210305,
#   '일일확진자': 398.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210306,
#   '일일확진자': 418.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210307,
#   '일일확진자': 416.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210308,
#   '일일확진자': 346.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210309,
#   '일일확진자': 446.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210310,
#   '일일확진자': 470.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210311,
#   '일일확진자': 465.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210312,
#   '일일확진자': 488.0,
#   '일일사망자': 10.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210313,
#   '일일확진자': 490.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210314,
#   '일일확진자': 459.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210315,
#   '일일확진자': 379.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210316,
#   '일일확진자': 363.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210317,
#   '일일확진자': 469.0,
#   '일일사망자': 8.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210318,
#   '일일확진자': 445.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210319,
#   '일일확진자': 463.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210320,
#   '일일확진자': 447.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210321,
#   '일일확진자': 456.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210322,
#   '일일확진자': 415.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210323,
#   '일일확진자': 346.0,
#   '일일사망자': 7.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210324,
#   '일일확진자': 428.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210325,
#   '일일확진자': 430.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210326,
#   '일일확진자': 489.0,
#   '일일사망자': 7.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210327,
#   '일일확진자': 505.0,
#   '일일사망자': 5.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210328,
#   '일일확진자': 482.0,
#   '일일사망자': 1.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210329,
#   '일일확진자': 382.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210330,
#   '일일확진자': 447.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210331,
#   '일일확진자': 506.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210401,
#   '일일확진자': 551.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210402,
#   '일일확진자': 557.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210403,
#   '일일확진자': 543.0,
#   '일일사망자': 3.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210404,
#   '일일확진자': 543.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210405,
#   '일일확진자': 473.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210406,
#   '일일확진자': 477.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210407,
#   '일일확진자': 668.0,
#   '일일사망자': 4.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210408,
#   '일일확진자': 700.0,
#   '일일사망자': 2.0,
#   'stateTime': '00:00',
#   'updateDt': '2021-10-07 10:30:51.51'},
#  {'stateDt': 20210409,
#   '일일확진자': 671.0,
# ...
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:04:29.013'},
#  {'stateDt': 20220203,
#   '일일확진자': 22906.0,
#   '일일사망자': 25.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:04:42.741'},
#  {'stateDt': 20220204,
#   '일일확진자': 27438.0,
#   '일일사망자': 24.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:04:52.382'},
#  {'stateDt': 20220205,
#   '일일확진자': 36345.0,
#   '일일사망자': 22.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:05:01.221'},
#  {'stateDt': 20220206,
#   '일일확진자': 38689.0,
#   '일일사망자': 15.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:05:11.818'},
#  {'stateDt': 20220207,
#   '일일확진자': 35283.0,
#   '일일사망자': 13.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:05:22.271'},
#  {'stateDt': 20220208,
#   '일일확진자': 36717.0,
#   '일일사망자': 36.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-09 13:05:32.357'},
#  {'stateDt': 20220209,
#   '일일확진자': 49567.0,
#   '일일사망자': 21.0,
#   'stateTime': '00:00',
#   'updateDt': nan},
#  {'stateDt': 20220210,
#   '일일확진자': 54122.0,
#   '일일사망자': 20.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-10 09:06:18.131'},
#  {'stateDt': 20220211,
#   '일일확진자': 53903.0,
#   '일일사망자': 49.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-12 22:25:54.07'},
#  {'stateDt': 20220212,
#   '일일확진자': 54935.0,
#   '일일사망자': 33.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-13 08:50:59.578'},
#  {'stateDt': 20220213,
#   '일일확진자': 56428.0,
#   '일일사망자': 36.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-14 09:03:09.631'},
#  {'stateDt': 20220214,
#   '일일확진자': 54617.0,
#   '일일사망자': 21.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-15 09:02:24.905'},
#  {'stateDt': 20220215,
#   '일일확진자': 57164.0,
#   '일일사망자': 61.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-16 09:20:55.138'},
#  {'stateDt': 20220216,
#   '일일확진자': 90435.0,
#   '일일사망자': 39.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-17 08:52:33.561'},
#  {'stateDt': 20220217,
#   '일일확진자': 93132.0,
#   '일일사망자': 36.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-18 09:05:35.842'},
#  {'stateDt': 20220218,
#   '일일확진자': 109823.0,
#   '일일사망자': 45.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-19 09:00:52.083'},
#  {'stateDt': 20220219,
#   '일일확진자': 102210.0,
#   '일일사망자': 71.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-20 08:52:45.133'},
#  {'stateDt': 20220220,
#   '일일확진자': 104814.0,
#   '일일사망자': 51.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-21 09:05:38.992'},
#  {'stateDt': 20220221,
#   '일일확진자': 95339.0,
#   '일일사망자': 45.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-22 09:07:07.41'},
#  {'stateDt': 20220222,
#   '일일확진자': 99569.0,
#   '일일사망자': 58.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-23 09:13:50.655'},
#  {'stateDt': 20220223,
#   '일일확진자': 171442.0,
#   '일일사망자': 99.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-24 09:46:50.038'},
#  {'stateDt': 20220224,
#   '일일확진자': 170015.0,
#   '일일사망자': 82.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-25 09:19:57.585'},
#  {'stateDt': 20220225,
#   '일일확진자': 165887.0,
#   '일일사망자': 94.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-02-26 09:11:20.409'},
#  {'stateDt': 20220226,
#   '일일확진자': 166182.0,
#   '일일사망자': 112.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:45:32.611'},
#  {'stateDt': 20220227,
#   '일일확진자': 163561.0,
#   '일일사망자': 49.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:43:04.008'},
#  {'stateDt': 20220228,
#   '일일확진자': 139624.0,
#   '일일사망자': 114.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:42:40.367'},
#  {'stateDt': 20220301,
#   '일일확진자': 138990.0,
#   '일일사망자': 112.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:42:18.383'},
#  {'stateDt': 20220302,
#   '일일확진자': 219228.0,
#   '일일사망자': 96.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:42:03.65'},
#  {'stateDt': 20220303,
#   '일일확진자': 198800.0,
#   '일일사망자': 128.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:41:48.252'},
#  {'stateDt': 20220304,
#   '일일확진자': 266850.0,
#   '일일사망자': 186.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:41:30.29'},
#  {'stateDt': 20220305,
#   '일일확진자': 254327.0,
#   '일일사망자': 216.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-06 09:41:13.104'},
#  {'stateDt': 20220306,
#   '일일확진자': 243625.0,
#   '일일사망자': 161.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-07 09:06:48.272'},
#  {'stateDt': 20220307,
#   '일일확진자': 210709.0,
#   '일일사망자': 139.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-08 08:58:58.236'},
#  {'stateDt': 20220308,
#   '일일확진자': 202702.0,
#   '일일사망자': 186.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-09 08:58:41.872'},
#  {'stateDt': 20220309,
#   '일일확진자': 342429.0,
#   '일일사망자': 158.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-10 09:08:10.52'},
#  {'stateDt': 20220310,
#   '일일확진자': 327538.0,
#   '일일사망자': 206.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-11 08:57:08.866'},
#  {'stateDt': 20220311,
#   '일일확진자': 282973.0,
#   '일일사망자': 229.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-19 09:48:19.456'},
#  {'stateDt': 20220312,
#   '일일확진자': 383617.0,
#   '일일사망자': 269.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-19 09:47:59.929'},
#  {'stateDt': 20220313,
#   '일일확진자': 350182.0,
#   '일일사망자': 251.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-19 09:47:34.07'},
#  {'stateDt': 20220314,
#   '일일확진자': 309779.0,
#   '일일사망자': 200.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-19 09:47:04.422'},
#  {'stateDt': 20220315,
#   '일일확진자': 362283.0,
#   '일일사망자': 293.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-22 09:00:06.26'},
#  {'stateDt': 20220316,
#   '일일확진자': 400593.0,
#   '일일사망자': 164.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-23 09:20:49.513'},
#  {'stateDt': 20220317,
#   '일일확진자': 621204.0,
#   '일일사망자': 429.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-24 09:06:26.685'},
#  {'stateDt': 20220318,
#   '일일확진자': 406839.0,
#   '일일사망자': 301.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-25 09:08:11.617'},
#  {'stateDt': 20220319,
#   '일일확진자': 381413.0,
#   '일일사망자': 319.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-25 09:07:49.638'},
#  {'stateDt': 20220320,
#   '일일확진자': 334653.0,
#   '일일사망자': 327.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-25 09:07:29.159'},
#  {'stateDt': 20220321,
#   '일일확진자': 209139.0,
#   '일일사망자': 329.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-25 09:07:01.306'},
#  {'stateDt': 20220322,
#   '일일확진자': 353828.0,
#   '일일사망자': 384.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-29 09:12:46.454'},
#  {'stateDt': 20220323,
#   '일일확진자': 490771.0,
#   '일일사망자': 291.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-30 09:09:59.926'},
#  {'stateDt': 20220324,
#   '일일확진자': 395526.0,
#   '일일사망자': 469.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-03-31 09:07:42.756'},
#  {'stateDt': 20220325,
#   '일일확진자': 339451.0,
#   '일일사망자': 393.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-01 09:07:43.379'},
#  {'stateDt': 20220326,
#   '일일확진자': 335541.0,
#   '일일사망자': 323.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-01 09:07:16.344'},
#  {'stateDt': 20220327,
#   '일일확진자': 318075.0,
#   '일일사망자': 282.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-01 09:07:01.085'},
#  {'stateDt': 20220328,
#   '일일확진자': 187182.0,
#   '일일사망자': 287.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-01 09:06:45.033'},
#  {'stateDt': 20220329,
#   '일일확진자': 347500.0,
#   '일일사망자': 237.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-01 09:06:30.566'},
#  {'stateDt': 20220330,
#   '일일확진자': 424466.0,
#   '일일사망자': 432.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-06 13:45:06.86'},
#  {'stateDt': 20220331,
#   '일일확진자': 320683.0,
#   '일일사망자': 375.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-07 09:08:39.321'},
#  {'stateDt': 20220401,
#   '일일확진자': 280231.0,
#   '일일사망자': 360.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-08 09:09:14.895'},
#  {'stateDt': 20220402,
#   '일일확진자': 264120.0,
#   '일일사망자': 339.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-09 09:24:07.877'},
#  {'stateDt': 20220403,
#   '일일확진자': 234265.0,
#   '일일사망자': 306.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-09 09:23:35.402'},
#  {'stateDt': 20220404,
#   '일일확진자': 127163.0,
#   '일일사망자': 218.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-09 09:23:05.652'},
#  {'stateDt': 20220405,
#   '일일확진자': 266085.0,
#   '일일사망자': 209.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-12 09:10:13.425'},
#  {'stateDt': 20220406,
#   '일일확진자': 286247.0,
#   '일일사망자': 371.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-13 09:10:16.582'},
#  {'stateDt': 20220407,
#   '일일확진자': 224784.0,
#   '일일사망자': 348.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-14 09:10:37.437'},
#  {'stateDt': 20220408,
#   '일일확진자': 205299.0,
#   '일일사망자': 373.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-15 09:02:28.696'},
#  {'stateDt': 20220409,
#   '일일확진자': 185525.0,
#   '일일사망자': 338.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-16 09:26:26.083'},
#  {'stateDt': 20220410,
#   '일일확진자': 164456.0,
#   '일일사망자': 329.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-16 09:26:12.275'},
#  {'stateDt': 20220411,
#   '일일확진자': 90917.0,
#   '일일사망자': 258.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-16 09:25:56.127'},
#  {'stateDt': 20220412,
#   '일일확진자': 210715.0,
#   '일일사망자': 171.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-19 09:07:50.743'},
#  {'stateDt': 20220413,
#   '일일확진자': 195382.0,
#   '일일사망자': 184.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-20 09:08:04.743'},
#  {'stateDt': 20220414,
#   '일일확진자': 148409.0,
#   '일일사망자': 318.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-21 09:13:41.99'},
#  {'stateDt': 20220415,
#   '일일확진자': 125800.0,
#   '일일사망자': 264.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-22 09:10:59.181'},
#  {'stateDt': 20220416,
#   '일일확진자': 107882.0,
#   '일일사망자': 273.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-23 09:58:40.198'},
#  {'stateDt': 20220417,
#   '일일확진자': 92978.0,
#   '일일사망자': 203.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-23 09:58:26.82'},
#  {'stateDt': 20220418,
#   '일일확진자': 47730.0,
#   '일일사망자': 132.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-23 09:58:10.581'},
#  {'stateDt': 20220419,
#   '일일확진자': 118462.0,
#   '일일사망자': 130.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-26 09:12:56.04'},
#  {'stateDt': 20220420,
#   '일일확진자': 111289.0,
#   '일일사망자': 166.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-27 09:03:39.849'},
#  {'stateDt': 20220421,
#   '일일확진자': 90843.0,
#   '일일사망자': 147.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-28 09:04:37.11'},
#  {'stateDt': 20220422,
#   '일일확진자': 81033.0,
#   '일일사망자': 206.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-29 09:05:42.917'},
#  {'stateDt': 20220423,
#   '일일확진자': 75423.0,
#   '일일사망자': 151.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-30 09:24:15.874'},
#  {'stateDt': 20220424,
#   '일일확진자': 64704.0,
#   '일일사망자': 109.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-30 09:25:01.983'},
#  {'stateDt': 20220425,
#   '일일확진자': 34361.0,
#   '일일사망자': 110.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-30 09:23:49.525'},
#  {'stateDt': 20220426,
#   '일일확진자': 80267.0,
#   '일일사망자': 82.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-03 09:11:15.127'},
#  {'stateDt': 20220427,
#   '일일확진자': 76764.0,
#   '일일사망자': 141.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-04 09:13:13.366'},
#  {'stateDt': 20220428,
#   '일일확진자': 57446.0,
#   '일일사망자': 122.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-05 09:26:29.55'},
#  {'stateDt': 20220429,
#   '일일확진자': 50556.0,
#   '일일사망자': 136.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-05 09:26:15.183'},
#  {'stateDt': 20220430,
#   '일일확진자': 43244.0,
#   '일일사망자': 70.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-07 09:21:13.949'},
#  {'stateDt': 20220501,
#   '일일확진자': 37760.0,
#   '일일사망자': 81.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-07 09:20:49.891'},
#  {'stateDt': 20220502,
#   '일일확진자': 20076.0,
#   '일일사망자': 83.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-07 09:20:27.275'},
#  {'stateDt': 20220503,
#   '일일확진자': 51106.0,
#   '일일사망자': 49.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-10 10:09:55.309'},
#  {'stateDt': 20220504,
#   '일일확진자': 49046.0,
#   '일일사망자': 72.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-11 09:03:27.014'},
#  {'stateDt': 20220505,
#   '일일확진자': 42279.0,
#   '일일사망자': 79.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-12 09:06:57.564'},
#  {'stateDt': 20220506,
#   '일일확진자': 26678.0,
#   '일일사망자': 48.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-13 09:11:27.572'},
#  {'stateDt': 20220507,
#   '일일확진자': 39563.0,
#   '일일사망자': 83.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-14 10:35:34.039'},
#  {'stateDt': 20220508,
#   '일일확진자': 40048.0,
#   '일일사망자': 71.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-14 10:35:16.208'},
#  {'stateDt': 20220509,
#   '일일확진자': 20588.0,
#   '일일사망자': 40.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-14 10:34:58.518'},
#  {'stateDt': 20220510,
#   '일일확진자': 49896.0,
#   '일일사망자': 62.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-17 09:06:40.689'},
#  {'stateDt': 20220511,
#   '일일확진자': 43881.0,
#   '일일사망자': 29.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-19 17:38:10.681'},
#  {'stateDt': 20220512,
#   '일일확진자': 35882.0,
#   '일일사망자': 63.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-19 17:37:18.336'},
#  {'stateDt': 20220513,
#   '일일확진자': 32435.0,
#   '일일사망자': 52.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-20 09:06:42.817'},
#  {'stateDt': 20220514,
#   '일일확진자': 29572.0,
#   '일일사망자': 55.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-21 08:48:13.125'},
#  {'stateDt': 20220515,
#   '일일확진자': 25425.0,
#   '일일사망자': 48.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-21 08:47:54.484'},
#  {'stateDt': 20220516,
#   '일일확진자': 13290.0,
#   '일일사망자': 35.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-21 08:47:40.875'},
#  {'stateDt': 20220517,
#   '일일확진자': 35085.0,
#   '일일사망자': 27.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-24 09:18:48.656'},
#  {'stateDt': 20220518,
#   '일일확진자': 31333.0,
#   '일일사망자': 31.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-25 09:05:49.683'},
#  {'stateDt': 20220519,
#   '일일확진자': 28109.0,
#   '일일사망자': 40.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-26 09:16:54.036'},
#  {'stateDt': 20220520,
#   '일일확진자': 25113.0,
#   '일일사망자': 43.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-27 09:04:41.621'},
#  {'stateDt': 20220521,
#   '일일확진자': 23450.0,
#   '일일사망자': 26.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-28 09:10:27.211'},
#  {'stateDt': 20220522,
#   '일일확진자': 19289.0,
#   '일일사망자': 54.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-28 09:10:20.33'},
#  {'stateDt': 20220523,
#   '일일확진자': 9971.0,
#   '일일사망자': 22.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-28 09:10:13.674'},
#  {'stateDt': 20220524,
#   '일일확진자': 26331.0,
#   '일일사망자': 19.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-31 08:58:44.451'},
#  {'stateDt': 20220525,
#   '일일확진자': 23936.0,
#   '일일사망자': 23.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-01 09:08:25.254'},
#  {'stateDt': 20220526,
#   '일일확진자': 18805.0,
#   '일일사망자': 34.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-01 09:08:19.164'},
#  {'stateDt': 20220527,
#   '일일확진자': 16572.0,
#   '일일사망자': 40.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-03 09:11:10.578'},
#  {'stateDt': 20220528,
#   '일일확진자': 14374.0,
#   '일일사망자': 36.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-04 09:00:06.316'},
#  {'stateDt': 20220529,
#   '일일확진자': 12647.0,
#   '일일사망자': 19.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-04 08:59:51.863'},
#  {'stateDt': 20220530,
#   '일일확진자': 6135.0,
#   '일일사망자': 9.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-04 08:59:37.203'},
#  {'stateDt': 20220531,
#   '일일확진자': 17185.0,
#   '일일사망자': 9.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-04 08:59:23.637'},
#  {'stateDt': 20220601,
#   '일일확진자': 15768.0,
#   '일일사망자': 21.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:12:05.316'},
#  {'stateDt': 20220602,
#   '일일확진자': 9891.0,
#   '일일사망자': 15.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:11:51.985'},
#  {'stateDt': 20220603,
#   '일일확진자': 12539.0,
#   '일일사망자': 17.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:11:38.938'},
#  {'stateDt': 20220604,
#   '일일확진자': 12039.0,
#   '일일사망자': 9.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:11:26.303'},
#  {'stateDt': 20220605,
#   '일일확진자': 9834.0,
#   '일일사망자': 20.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:11:04.758'},
#  {'stateDt': 20220606,
#   '일일확진자': 5022.0,
#   '일일사망자': 21.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:10:50.441'},
#  {'stateDt': 20220607,
#   '일일확진자': 6172.0,
#   '일일사망자': 20.0,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:10:36.846'},
#  {'stateDt': 20220608,
#   '일일확진자': 13358.0,
#   '일일사망자': 6.0,
#   'stateTime': '00:00',
#   'updateDt': nan}]

# %%
print(f'데이터프레임의 컬럼의 목록 : {col_list}')
print(f'데이터프레임 딕셔너리형 반환 : {dict_data[0]}')
# Out:
# 데이터프레임의 컬럼의 목록 : ['stateDt', '일일확진자', '일일사망자', 'stateTime', 'updateDt']
# 데이터프레임 딕셔너리형 반환 : {'stateDt': 20200310, '일일확진자': 0.0, '일일사망자': 0.0, 'stateTime': '00:00', 'updateDt': '2021-10-07 10:30:51.51'}

# %%
date
# Out:
# np.int64(20220608)

# %%
date = str(date)
date
# Out:
# '20220608'

# %%
date = date[:4]+'년'+date[4:6]+'월'+date[6:]+'일'
date
# Out:
# '2022년06월08일'

# %%
df = corona[ ['stateDt', '일일확진자', '일일사망자', 'stateTime', 'updateDt'] ]
df
# Out:
#       stateDt    일일확진자  일일사망자 stateTime                 updateDt
# 819  20200310      0.0    0.0     00:00   2021-10-07 10:30:51.51
# 818  20200311    242.0    6.0     00:00   2021-10-07 10:30:51.51
# 817  20200312    114.0    6.0     00:00   2021-10-07 10:30:51.51
# 816  20200313    110.0    1.0     00:00   2021-10-07 10:30:51.51
# 815  20200314    107.0    5.0     00:00   2021-10-07 10:30:51.51
# ..        ...      ...    ...       ...                      ...
# 4    20220604  12039.0    9.0     00:00  2022-06-08 09:11:26.303
# 3    20220605   9834.0   20.0     00:00  2022-06-08 09:11:04.758
# 2    20220606   5022.0   21.0     00:00  2022-06-08 09:10:50.441
# 1    20220607   6172.0   20.0     00:00  2022-06-08 09:10:36.846
# 0    20220608  13358.0    6.0     00:00                      NaN
#
# [820 rows x 5 columns]

# %%
x = df['stateDt'].to_list()
y = df['일일확진자'].to_list()

# %%
y
# Out:
# [0.0,
#  242.0,
#  114.0,
#  110.0,
#  107.0,
#  76.0,
#  74.0,
#  84.0,
#  93.0,
#  152.0,
#  87.0,
#  147.0,
#  98.0,
#  64.0,
#  76.0,
#  100.0,
#  104.0,
#  91.0,
#  146.0,
#  105.0,
#  78.0,
#  125.0,
#  101.0,
#  89.0,
#  86.0,
#  94.0,
#  81.0,
#  47.0,
#  47.0,
#  53.0,
#  39.0,
#  27.0,
#  30.0,
#  32.0,
#  25.0,
#  27.0,
#  27.0,
#  22.0,
#  22.0,
#  18.0,
#  8.0,
#  13.0,
#  9.0,
#  11.0,
#  8.0,
#  6.0,
#  10.0,
#  10.0,
#  10.0,
#  14.0,
#  9.0,
#  4.0,
#  9.0,
#  6.0,
#  13.0,
#  8.0,
#  3.0,
#  2.0,
#  4.0,
#  12.0,
#  18.0,
#  34.0,
#  35.0,
#  27.0,
#  26.0,
#  56.0,
#  19.0,
#  13.0,
#  15.0,
#  13.0,
#  32.0,
#  12.0,
#  20.0,
#  23.0,
#  25.0,
#  16.0,
#  19.0,
#  40.0,
#  79.0,
#  58.0,
#  39.0,
#  27.0,
#  35.0,
#  38.0,
#  49.0,
#  39.0,
#  39.0,
#  51.0,
#  57.0,
#  37.0,
#  38.0,
#  50.0,
#  45.0,
#  56.0,
#  48.0,
#  34.0,
#  37.0,
#  34.0,
#  43.0,
#  59.0,
#  49.0,
#  67.0,
#  48.0,
#  17.0,
#  46.0,
#  51.0,
#  28.0,
#  39.0,
#  51.0,
#  62.0,
#  42.0,
#  42.0,
#  51.0,
#  54.0,
#  61.0,
#  63.0,
#  61.0,
#  48.0,
#  44.0,
#  62.0,
#  50.0,
#  45.0,
#  35.0,
#  44.0,
#  62.0,
#  33.0,
#  39.0,
#  61.0,
#  60.0,
#  39.0,
#  34.0,
#  26.0,
#  45.0,
#  63.0,
#  59.0,
#  41.0,
#  113.0,
#  58.0,
#  25.0,
#  28.0,
#  48.0,
#  18.0,
#  36.0,
#  31.0,
#  30.0,
#  23.0,
#  34.0,
#  33.0,
#  43.0,
#  20.0,
#  43.0,
#  36.0,
#  28.0,
#  34.0,
#  54.0,
#  56.0,
#  103.0,
#  166.0,
#  279.0,
#  197.0,
#  246.0,
#  297.0,
#  288.0,
#  324.0,
#  332.0,
#  396.0,
#  266.0,
#  280.0,
#  320.0,
#  441.0,
#  371.0,
#  323.0,
#  299.0,
#  248.0,
#  235.0,
#  267.0,
#  195.0,
#  198.0,
#  168.0,
#  167.0,
#  119.0,
#  136.0,
#  156.0,
#  155.0,
#  176.0,
#  136.0,
#  121.0,
#  109.0,
#  106.0,
#  113.0,
#  153.0,
#  126.0,
#  110.0,
#  82.0,
#  70.0,
#  61.0,
#  110.0,
#  125.0,
#  114.0,
#  61.0,
#  95.0,
#  50.0,
#  38.0,
#  113.0,
#  77.0,
#  63.0,
#  75.0,
#  64.0,
#  73.0,
#  75.0,
#  114.0,
#  69.0,
#  54.0,
#  72.0,
#  58.0,
#  98.0,
#  91.0,
#  84.0,
#  110.0,
#  47.0,
#  73.0,
#  91.0,
#  76.0,
#  58.0,
#  89.0,
#  121.0,
#  155.0,
#  77.0,
#  61.0,
#  119.0,
#  88.0,
#  103.0,
#  125.0,
#  113.0,
#  127.0,
#  124.0,
#  97.0,
#  75.0,
#  117.0,
#  125.0,
#  145.0,
#  89.0,
#  143.0,
#  126.0,
#  100.0,
#  145.0,
#  143.0,
#  191.0,
#  205.0,
#  208.0,
#  222.0,
#  230.0,
#  285.0,
#  325.0,
#  348.0,
#  386.0,
#  330.0,
#  271.0,
#  349.0,
#  382.0,
#  581.0,
#  555.0,
#  503.0,
#  450.0,
#  438.0,
#  451.0,
#  511.0,
#  540.0,
#  628.0,
#  577.0,
#  631.0,
#  615.0,
#  587.0,
#  670.0,
#  680.0,
#  689.0,
#  950.0,
#  1030.0,
#  718.0,
#  880.0,
#  1078.0,
#  1014.0,
#  1064.0,
#  1045.0,
#  1096.0,
#  924.0,
#  866.0,
#  1090.0,
#  985.0,
#  1240.0,
#  1131.0,
#  970.0,
#  806.0,
#  1044.0,
#  1050.0,
#  967.0,
#  1027.0,
#  820.0,
#  657.0,
#  1020.0,
#  714.0,
#  838.0,
#  869.0,
#  674.0,
#  641.0,
#  657.0,
#  451.0,
#  537.0,
#  561.0,
#  524.0,
#  512.0,
#  580.0,
#  520.0,
#  389.0,
#  386.0,
#  404.0,
#  400.0,
#  346.0,
#  431.0,
#  392.0,
#  437.0,
#  349.0,
#  559.0,
#  497.0,
#  469.0,
#  456.0,
#  354.0,
#  305.0,
#  336.0,
#  467.0,
#  451.0,
#  370.0,
#  390.0,
#  371.0,
#  288.0,
#  303.0,
#  444.0,
#  504.0,
#  403.0,
#  362.0,
#  326.0,
#  343.0,
#  457.0,
#  621.0,
#  621.0,
#  561.0,
#  448.0,
#  416.0,
#  332.0,
#  356.0,
#  440.0,
#  395.0,
#  387.0,
#  415.0,
#  355.0,
#  355.0,
#  344.0,
#  444.0,
#  424.0,
#  398.0,
#  418.0,
#  416.0,
#  346.0,
#  446.0,
#  470.0,
#  465.0,
#  488.0,
#  490.0,
#  459.0,
#  379.0,
#  363.0,
#  469.0,
#  445.0,
#  463.0,
#  447.0,
#  456.0,
#  415.0,
#  346.0,
#  428.0,
#  430.0,
#  489.0,
#  505.0,
#  482.0,
#  382.0,
#  447.0,
#  506.0,
#  551.0,
#  557.0,
#  543.0,
#  543.0,
#  473.0,
#  477.0,
#  668.0,
#  700.0,
#  671.0,
#  677.0,
#  614.0,
#  587.0,
#  542.0,
#  731.0,
#  698.0,
#  673.0,
#  658.0,
#  671.0,
#  532.0,
#  549.0,
#  731.0,
#  735.0,
#  797.0,
#  785.0,
#  644.0,
#  499.0,
#  512.0,
#  769.0,
#  679.0,
#  661.0,
#  627.0,
#  606.0,
#  488.0,
#  541.0,
#  676.0,
#  574.0,
#  525.0,
#  701.0,
#  564.0,
#  463.0,
#  510.0,
#  634.0,
#  715.0,
#  747.0,
#  681.0,
#  610.0,
#  619.0,
#  528.0,
#  654.0,
#  646.0,
#  561.0,
#  666.0,
#  585.0,
#  530.0,
#  516.0,
#  705.0,
#  629.0,
#  587.0,
#  533.0,
#  480.0,
#  430.0,
#  459.0,
#  677.0,
#  681.0,
#  695.0,
#  744.0,
#  556.0,
#  485.0,
#  454.0,
#  602.0,
#  610.0,
#  556.0,
#  565.0,
#  452.0,
#  399.0,
#  373.0,
#  545.0,
#  540.0,
#  507.0,
#  482.0,
#  429.0,
#  357.0,
#  394.0,
#  645.0,
#  610.0,
#  634.0,
#  668.0,
#  614.0,
#  501.0,
#  595.0,
#  794.0,
#  761.0,
#  825.0,
#  794.0,
#  743.0,
#  711.0,
#  746.0,
#  1211.0,
#  1275.0,
#  1316.0,
#  1378.0,
#  1324.0,
#  1100.0,
#  1150.0,
#  1613.0,
#  1599.0,
#  1535.0,
#  1449.0,
#  1453.0,
#  1251.0,
#  1278.0,
#  1781.0,
#  1841.0,
#  1629.0,
#  1627.0,
#  1487.0,
#  1318.0,
#  1363.0,
#  1895.0,
#  1673.0,
#  1710.0,
#  1538.0,
#  1442.0,
#  1218.0,
#  1200.0,
#  1725.0,
#  1775.0,
#  1704.0,
#  1823.0,
#  1727.0,
#  1491.0,
#  1537.0,
#  2221.0,
#  1987.0,
#  1989.0,
#  1928.0,
#  1816.0,
#  1554.0,
#  1372.0,
#  1803.0,
#  2152.0,
#  2140.0,
#  1787.0,
#  1626.0,
#  1417.0,
#  1507.0,
#  2154.0,
#  1882.0,
#  1837.0,
#  1791.0,
#  1619.0,
#  1485.0,
#  1370.0,
#  2024.0,
#  1960.0,
#  1708.0,
#  1803.0,
#  1490.0,
#  1375.0,
#  1597.0,
#  2047.0,
#  2049.0,
#  1893.0,
#  1864.0,
#  1755.0,
#  1433.0,
#  1508.0,
#  2065.0,
#  1942.0,
#  2008.0,
#  2087.0,
#  1909.0,
#  1604.0,
#  1729.0,
#  1720.0,
#  1715.0,
#  2429.0,
#  3270.0,
#  2768.0,
#  2381.0,
#  2288.0,
#  2881.0,
#  2561.0,
#  2484.0,
#  2247.0,
#  2085.0,
#  1670.0,
#  1574.0,
#  2027.0,
#  2425.0,
#  2171.0,
#  1953.0,
#  1594.0,
#  1297.0,
#  1346.0,
#  1583.0,
#  1939.0,
#  1683.0,
#  1617.0,
#  1420.0,
#  1050.0,
#  1073.0,
#  1571.0,
#  1441.0,
#  1438.0,
#  1508.0,
#  1421.0,
#  1190.0,
#  1272.0,
#  1945.0,
#  2111.0,
#  2121.0,
#  2104.0,
#  2061.0,
#  1685.0,
#  1588.0,
#  2667.0,
#  2482.0,
#  2343.0,
#  2246.0,
#  2225.0,
#  1754.0,
#  1717.0,
#  2425.0,
#  2518.0,
#  2368.0,
#  2324.0,
#  2418.0,
#  2004.0,
#  2122.0,
#  3189.0,
#  3292.0,
#  3033.0,
#  3205.0,
#  3120.0,
#  2827.0,
#  2697.0,
#  4113.0,
#  3937.0,
#  3896.0,
#  4067.0,
#  3925.0,
#  3307.0,
#  3031.0,
#  5122.0,
#  5263.0,
#  4944.0,
#  5352.0,
#  5125.0,
#  4324.0,
#  4953.0,
#  7173.0,
#  7375.0,
#  6748.0,
#  6977.0,
#  6681.0,
#  5816.0,
#  5567.0,
#  7849.0,
#  7619.0,
#  7434.0,
#  7310.0,
#  6233.0,
#  5316.0,
#  5192.0,
#  7452.0,
#  6914.0,
#  6233.0,
#  5840.0,
#  5413.0,
#  4203.0,
#  3864.0,
#  5407.0,
#  5034.0,
#  4873.0,
#  4415.0,
#  3831.0,
#  3125.0,
#  3021.0,
#  4441.0,
#  4122.0,
#  3713.0,
#  3507.0,
#  3371.0,
#  3005.0,
#  3092.0,
#  4383.0,
#  4164.0,
#  4538.0,
#  4419.0,
#  4189.0,
#  3854.0,
#  4062.0,
#  5803.0,
#  6600.0,
#  6766.0,
#  7004.0,
#  7626.0,
#  7511.0,
#  8570.0,
#  13009.0,
#  14514.0,
#  16093.0,
#  17513.0,
#  17522.0,
#  17077.0,
#  18338.0,
#  20268.0,
#  22906.0,
#  27438.0,
#  36345.0,
#  38689.0,
#  35283.0,
#  36717.0,
#  49567.0,
#  54122.0,
#  53903.0,
#  54935.0,
#  56428.0,
#  54617.0,
#  57164.0,
#  90435.0,
#  93132.0,
#  109823.0,
#  102210.0,
#  104814.0,
#  95339.0,
#  99569.0,
#  171442.0,
#  170015.0,
#  165887.0,
#  166182.0,
#  163561.0,
#  139624.0,
#  138990.0,
#  219228.0,
#  198800.0,
#  266850.0,
#  254327.0,
#  243625.0,
#  210709.0,
#  202702.0,
#  342429.0,
#  327538.0,
#  282973.0,
#  383617.0,
#  350182.0,
#  309779.0,
#  362283.0,
#  400593.0,
#  621204.0,
#  406839.0,
#  381413.0,
#  334653.0,
#  209139.0,
#  353828.0,
#  490771.0,
#  395526.0,
#  339451.0,
#  335541.0,
#  318075.0,
#  187182.0,
#  347500.0,
#  424466.0,
#  320683.0,
#  280231.0,
#  264120.0,
#  234265.0,
#  127163.0,
#  266085.0,
#  286247.0,
#  224784.0,
#  205299.0,
#  185525.0,
#  164456.0,
#  90917.0,
#  210715.0,
#  195382.0,
#  148409.0,
#  125800.0,
#  107882.0,
#  92978.0,
#  47730.0,
#  118462.0,
#  111289.0,
#  90843.0,
#  81033.0,
#  75423.0,
#  64704.0,
#  34361.0,
#  80267.0,
#  76764.0,
#  57446.0,
#  50556.0,
#  43244.0,
#  37760.0,
#  20076.0,
#  51106.0,
#  49046.0,
#  42279.0,
#  26678.0,
#  39563.0,
#  40048.0,
#  20588.0,
#  49896.0,
#  43881.0,
#  35882.0,
#  32435.0,
#  29572.0,
#  25425.0,
#  13290.0,
#  35085.0,
#  31333.0,
#  28109.0,
#  25113.0,
#  23450.0,
#  19289.0,
#  9971.0,
#  26331.0,
#  23936.0,
#  18805.0,
#  16572.0,
#  14374.0,
#  12647.0,
#  6135.0,
#  17185.0,
#  15768.0,
#  9891.0,
#  12539.0,
#  12039.0,
#  9834.0,
#  5022.0,
#  6172.0,
#  13358.0]
